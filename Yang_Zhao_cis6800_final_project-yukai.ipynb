# %%
if 'google.colab' in str(get_ipython()):
    # Colab setup
    import os
    from google.colab import files
    from google.colab import drive

    proj_path = "/content/gdrive/My Drive/CIS680/project"
    data_path = os.path.join(proj_path, "data")
    drive.mount("/content/gdrive")

    os.makedirs(data_path, exist_ok=True)
    os.chdir(proj_path)
# Out:
# Mounted at /content/gdrive

# %%
import argparse
import os
import itertools
import numpy as np
import time
import matplotlib.pyplot as plt

# Torch related
import torch
from torch import nn, optim

# %%
# Local modules
from vis_tools import visualizer
from datasets import Edge2Shoe
from models import (ResNetGenerator, UNetGenerator,
                    MultiPatchGANDiscriminator,
                    Encoder, weights_init_normal,
                    reparameterization, loss_KLD,
                    loss_discriminator, loss_generator
                    )

# %%
def norm(image):
    """
    Normalize image tensor
    """
    return (image / 255.0 - 0.5) * 2.0


def denorm(tensor):
    """
    Denormalize image tensor
    """
    return ((tensor + 1.0) / 2.0) * 255.0


def set_requires_grad(model, requires_grad):
    """
    Freeze or unfreeze model
    """
    for param in model.parameters():
        param.requires_grad = requires_grad

# %%
# Training Configurations
checkpoints_path = 'checkpoints/'
imgs_path = 'figures/'

exp_id = "unet_in_sep"
save_path = os.path.join(proj_path, exp_id)
if save_path:
    checkpoints_path = os.path.join(save_path, checkpoints_path)
    imgs_path = os.path.join(save_path, imgs_path)
os.makedirs(checkpoints_path, exist_ok=True)
os.makedirs(imgs_path, exist_ok=True)

img_dir = os.path.join(proj_path, 'data/edges2shoes/train/')
img_shape = (3, 128, 128)  # Please use this image dimension faster training purpose
n_residual_blocks = 6
num_epochs = 20
batch_size = 8
lr_rate = 2e-4	      # Adam optimizer learning rate
betas = (0.5, 0.999)    # Adam optimizer beta 1, beta 2
lambda_recon = 10      # Loss weights for reconstruction loss
lambda_latent = 0.5    # Loss weights for latent regression
lambda_kl = 0.01        # Loss weights for kl divergence
latent_dim = 8      # latent dimension for the encoded images from domain B
num_disc_scales = 1    # Number of discriminator scales
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Reparameterization helper function
# (You may need this helper function here or inside models.py, depending on your encoder
#   implementation)

# Random seeds (optional)
# torch.manual_seed(1)
# np.random.seed(1)

# Define DataLoader
dataset = Edge2Shoe(img_dir)
loader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=batch_size, num_workers=2, pin_memory=True)

# Loss functions
l1_loss = torch.nn.L1Loss().to(device)
mse_loss = torch.nn.MSELoss().to(device)

# Define generator, encoder and discriminators
# generator = ResNetGenerator(latent_dim, img_shape, n_residual_blocks).to(device)
generator = UNetGenerator(latent_dim, img_shape).to(device)
encoder = Encoder(latent_dim).to(device)
# Use 2 separate discriminators for cVAE-GAN and cLR-GAN
discriminator = MultiPatchGANDiscriminator(img_shape, num_scales=num_disc_scales).to(device)
discriminator2 = MultiPatchGANDiscriminator(img_shape, num_scales=num_disc_scales).to(device)

# init weights
generator.apply(weights_init_normal)
encoder.apply(weights_init_normal)
discriminator.apply(weights_init_normal)
discriminator2.apply(weights_init_normal)

# Define optimizers for networks
optimizer_E = torch.optim.Adam(encoder.parameters(), lr=lr_rate, betas=betas)
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr_rate, betas=betas)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr_rate, betas=betas)
optimizer_D2 = torch.optim.Adam(discriminator2.parameters(), lr=lr_rate, betas=betas)

# For adversarial loss (optional to use)
valid = 1
fake = 0

# Train loss list
list_vae_G_train_loss = []
list_clr_G_train_loss = []
list_kld_train_loss = []
list_recon_train_loss = []
list_GE_train_loss = []
list_latent_train_loss = []
list_vae_D_train_loss = []
list_clr_D_train_loss = []

# Training
total_steps = len(loader) * num_epochs
print(f"Total steps: {total_steps}")
for epoch_id in range(num_epochs):
    print(f"------------------------------------- Starting epoch {epoch_id} ---------------------------------------")
    avg_vae_G_train_loss = 0
    avg_clr_G_train_loss = 0
    avg_kld_train_loss = 0
    avg_recon_train_loss = 0
    avg_GE_train_loss = 0
    avg_latent_train_loss = 0
    avg_vae_D_train_loss = 0
    avg_clr_D_train_loss = 0

    start = time.time()
    for idx, data in enumerate(loader):
        # ######## Process Inputs ##########
        edge_tensor, rgb_tensor = data
        edge_tensor, rgb_tensor = norm(edge_tensor).to(device), norm(rgb_tensor).to(device)
        real_A = edge_tensor
        real_B = rgb_tensor

        # -------------------------------
        #  Forward
        # ------------------------------
        encoder.train()
        generator.train()

        z_mu, z_logvar = encoder.forward(rgb_tensor)
        z_encoded = reparameterization(z_mu, z_logvar)

        fake_B_encoded = generator.forward(real_A, z_encoded)

        z_random = torch.randn(real_A.shape[0], latent_dim).to(device)
        fake_B_random = generator.forward(real_A, z_random)

        z_mu_predict, z_logvar_predict = encoder.forward(fake_B_random)

        # -------------------------------
        #  Train Generator and Encoder
        # ------------------------------
        set_requires_grad(discriminator, False)
        set_requires_grad(discriminator2, False)

        optimizer_E.zero_grad()
        optimizer_G.zero_grad()

        # G(A) should fool D
        vae_G_loss = loss_generator(discriminator, fake_B_encoded, valid, mse_loss)
        clr_G_loss = loss_generator(discriminator2, fake_B_random, valid, mse_loss)

        # compute KLD loss
        kld_loss = loss_KLD(z_mu, z_logvar)

        # Compute L1 image loss
        recon_loss = l1_loss(fake_B_encoded, real_B)

        loss_GE = vae_G_loss + clr_G_loss + lambda_kl * kld_loss + lambda_recon * recon_loss
        loss_GE.backward(retain_graph=True)

        # Backward Latent space
        set_requires_grad(encoder, False)

        latent_loss = l1_loss(z_mu_predict, z_random) * lambda_latent
        latent_loss.backward()

        set_requires_grad(encoder, True)

        optimizer_E.step()
        optimizer_G.step()

        # -------------------------------
        #  Train Discriminators
        # ------------------------------
        set_requires_grad(discriminator, True)
        set_requires_grad(discriminator2, True)

        # Compute VAE-GAN discriminator loss
        optimizer_D.zero_grad()
        vae_D_loss = loss_discriminator(
            discriminator, fake_B_encoded, real_B, valid, fake, mse_loss)
        vae_D_loss.backward()
        optimizer_D.step()
        
        # Compute cLR-GAN discriminator loss
        optimizer_D2.zero_grad()
        clr_D_loss = loss_discriminator(
            discriminator2, fake_B_random, real_B, valid, fake, mse_loss)
        clr_D_loss.backward()
        optimizer_D2.step()

        # -------------------------------
        #  Aggregate losses
        # ------------------------------
        avg_vae_G_train_loss += vae_G_loss.item()
        avg_clr_G_train_loss += clr_G_loss.item()
        avg_kld_train_loss += kld_loss.item()
        avg_recon_train_loss += recon_loss.item()
        avg_GE_train_loss += loss_GE.item()
        avg_latent_train_loss += latent_loss.item()
        avg_vae_D_train_loss += vae_D_loss.item()
        avg_clr_D_train_loss += clr_D_loss.item()

        print("epoch {} iter {}; loss_GE: {:.4f}; loss_G: {:.4f}; loss_D: {:.4f}; latent: {:.4f}; KLD: {:.4f}".format(
            epoch_id, idx, loss_GE.item(),
            vae_G_loss.item() + clr_G_loss.item(),
            vae_D_loss.item() + clr_D_loss.item(),
            latent_loss.item(),
            kld_loss.item())
        )

        # -------------------------------
        #  Visualization
        # ------------------------------
        if (idx + 1) % 1000 == 0:
            vis_fake_B_encoded = denorm(fake_B_encoded[0].detach()).cpu().numpy().astype(np.uint8)
            vis_fake_B_random = denorm(fake_B_random[0].detach()).cpu().numpy().astype(np.uint8)
            vis_real_B = denorm(real_B[0].detach()).cpu().numpy().astype(np.uint8)
            vis_real_A = denorm(real_A[0].detach()).cpu().numpy().astype(np.uint8)
            fig, axs = plt.subplots(2, 2, figsize=(5, 5))

            axs[0, 0].set_title('real')
            axs[0, 0].imshow(vis_real_A.transpose(1, 2, 0))
            axs[1, 0].imshow(vis_real_B.transpose(1, 2, 0))
            axs[0, 1].set_title('generated')
            axs[0, 1].imshow(vis_fake_B_encoded.transpose(1, 2, 0))
            axs[1, 1].imshow(vis_fake_B_random.transpose(1, 2, 0))
            path = os.path.join(imgs_path, f'epoch_{epoch_id}_{idx}.png')
            plt.savefig(path)

    # -------------------------------
    #  Checkpoint
    # ------------------------------
    list_vae_G_train_loss.append(avg_vae_G_train_loss / len(loader))
    list_clr_G_train_loss.append(avg_clr_G_train_loss / len(loader))
    list_kld_train_loss.append(avg_kld_train_loss / len(loader))
    list_recon_train_loss.append(avg_recon_train_loss / len(loader))
    list_GE_train_loss.append(avg_GE_train_loss / len(loader))
    list_latent_train_loss.append(avg_latent_train_loss / len(loader))
    list_vae_D_train_loss.append(avg_vae_D_train_loss / len(loader))
    list_clr_D_train_loss.append(avg_clr_D_train_loss / len(loader))

    path = os.path.join(checkpoints_path, f'bicycleGAN_epoch_{epoch_id}')
    torch.save({
        'epoch': epoch_id,
        'encoder_state_dict': encoder.state_dict(),
        'generator_state_dict': generator.state_dict(),
        'discriminator_state_dict': discriminator.state_dict(),
        'discriminator2_state_dict': discriminator2.state_dict(),
        'optimizer_E': optimizer_E.state_dict(),
        'optimizer_G': optimizer_G.state_dict(),
        'optimizer_D': optimizer_D.state_dict(),
        'optimizer_D2': optimizer_D2.state_dict(),
        'list_vae_G_train_loss': list_vae_G_train_loss,
        'list_clr_G_train_loss': list_clr_G_train_loss,
        'list_kld_train_loss': list_kld_train_loss,
        'list_recon_train_loss': list_recon_train_loss,
        'list_GE_train_loss': list_GE_train_loss,
        'list_latent_train_loss': list_latent_train_loss,
        'list_vae_D_train_loss': list_vae_D_train_loss,
        'list_clr_D_train_loss': list_clr_D_train_loss
    }, path)

# %%
epoch_id = 19
path = os.path.join(checkpoints_path, f'bicycleGAN_epoch_{epoch_id}')
checkpoint = torch.load(path)
encoder.load_state_dict(checkpoint['encoder_state_dict'])
generator.load_state_dict(checkpoint['generator_state_dict'])
encoder.eval()
generator.eval()

# Plot training losses
list_vae_G_train_loss = checkpoint['list_vae_G_train_loss']
list_clr_G_train_loss = checkpoint['list_clr_G_train_loss']
list_kld_train_loss = checkpoint['list_kld_train_loss']
list_img_train_loss = checkpoint['list_recon_train_loss']
list_GE_train_loss = checkpoint['list_GE_train_loss']
list_latent_train_loss = checkpoint['list_latent_train_loss']
list_vae_D_train_loss = checkpoint['list_vae_D_train_loss']
list_clr_D_train_loss = checkpoint['list_clr_D_train_loss']

plt.close('all')
plt.figure()
fig, axs = plt.subplots(3, 3, figsize=(15, 10))
axs[0, 0].plot(list_vae_G_train_loss)
axs[0, 1].plot(list_clr_G_train_loss)
axs[0, 2].plot(list_kld_train_loss)
axs[1, 0].plot(list_recon_train_loss)
axs[1, 1].plot(list_GE_train_loss)
axs[1, 2].plot(list_latent_train_loss)
axs[2, 0].plot(list_vae_D_train_loss)
axs[2, 1].plot(list_clr_D_train_loss)
axs[0, 0].set_title('cVAE generator loss')
axs[0, 1].set_title('cLR generator loss')
axs[0, 2].set_title('cVAE KL divergence loss')
axs[1, 0].set_title('cVAE reconstruction loss')
axs[1, 1].set_title('Total generator encoder loss')
axs[1, 2].set_title('cLR latent loss')
axs[2, 0].set_title('cVAE discriminator loss')
axs[2, 1].set_title('cLR discriminator loss')
axs[2, 2].set_axis_off()
plt.tight_layout()
plt.savefig(os.path.join(exp_id, 'loss_curves.png'))

# %%
# !python infer.py --infer_random --exp_id {exp_id} --epoch_id {epoch_id}
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 209it [01:07,  3.10it/s]

# %%
# !python infer.py --infer_video --exp_id {exp_id} --epoch_id {epoch_id}
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 209it [00:01, 198.44it/s]

# %%
# !python infer.py --infer_encoded --exp_id {exp_id} --epoch_id {epoch_id}
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 90.2MB/s]
# 209it [05:50,  1.68s/it]

# %%
# !pip install pytorch-fid
# !python -m pytorch_fid {exp_id}/out_images_fid/real {exp_id}/out_images_fid/gen > {exp_id}/fid.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-fid
#   Downloading pytorch-fid-0.2.1.tar.gz (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pytorch-fid) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from pytorch-fid) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pytorch-fid) (1.7.3)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from pytorch-fid) (1.13.0+cu116)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from pytorch-fid) (0.14.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.0.1->pytorch-fid) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.2.2->pytorch-fid) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (3.0.4)
# Building wheels for collected packages: pytorch-fid
#   Building wheel for pytorch-fid (setup.py) ... done
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.1-py3-none-any.whl size=14834 sha256=61f72c66009351f6bff1d1b1248d90590fc360fd6b2c62f888fbe50fd29f4e14
#   Stored in directory: /root/.cache/pip/wheels/df/c8/a0/cce2ed7671ae52be132ae836e429bba6148544f83b7962b4bc
# Successfully built pytorch-fid
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.2.1
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:33<00:00, 2.89MB/s]
# 100% 5/5 [00:03<00:00,  1.64it/s]
# 100% 5/5 [00:01<00:00,  4.04it/s]

# %%
# !python infer.py --compute_lpips --exp_id {exp_id} --epoch_id {epoch_id}
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 209it [28:34,  8.21s/it]

# %%
# !pip install lpips
# !python lpips_all_dir.py -d {exp_id}/out_images_lpips/ -o {exp_id}/dists_pair.txt --use_gpu
# Out:
# Streaming output truncated to the last 5000 lines.
# (img_91_2.png,img_91_3.png): 0.032
# (img_91_2.png,img_91_4.png): 0.207
# (img_91_2.png,img_91_5.png): 0.112
# (img_91_2.png,img_91_6.png): 0.100
# (img_91_2.png,img_91_7.png): 0.380
# (img_91_2.png,img_91_8.png): 0.087
# (img_91_2.png,img_91_9.png): 0.235
# (img_91_3.png,img_91_4.png): 0.215
# (img_91_3.png,img_91_5.png): 0.079
# (img_91_3.png,img_91_6.png): 0.041
# (img_91_3.png,img_91_7.png): 0.357
# (img_91_3.png,img_91_8.png): 0.068
# (img_91_3.png,img_91_9.png): 0.251
# (img_91_4.png,img_91_5.png): 0.127
# (img_91_4.png,img_91_6.png): 0.205
# (img_91_4.png,img_91_7.png): 0.445
# (img_91_4.png,img_91_8.png): 0.099
# (img_91_4.png,img_91_9.png): 0.020
# (img_91_5.png,img_91_6.png): 0.041
# (img_91_5.png,img_91_7.png): 0.340
# (img_91_5.png,img_91_8.png): 0.027
# (img_91_5.png,img_91_9.png): 0.169
# (img_91_6.png,img_91_7.png): 0.335
# (img_91_6.png,img_91_8.png): 0.066
# (img_91_6.png,img_91_9.png): 0.248
# (img_91_7.png,img_91_8.png): 0.373
# (img_91_7.png,img_91_9.png): 0.462
# (img_91_8.png,img_91_9.png): 0.136
# Avg: 0.18814 +/- 0.01931
# (img_92_0.png,img_92_1.png): 0.034
# (img_92_0.png,img_92_2.png): 0.022
# (img_92_0.png,img_92_3.png): 0.355
# (img_92_0.png,img_92_4.png): 0.165
# (img_92_0.png,img_92_5.png): 0.049
# (img_92_0.png,img_92_6.png): 0.013
# (img_92_0.png,img_92_7.png): 0.006
# (img_92_0.png,img_92_8.png): 0.012
# (img_92_0.png,img_92_9.png): 0.012
# (img_92_1.png,img_92_2.png): 0.078
# (img_92_1.png,img_92_3.png): 0.330
# (img_92_1.png,img_92_4.png): 0.161
# (img_92_1.png,img_92_5.png): 0.005
# (img_92_1.png,img_92_6.png): 0.057
# (img_92_1.png,img_92_7.png): 0.051
# (img_92_1.png,img_92_8.png): 0.041
# (img_92_1.png,img_92_9.png): 0.039
# (img_92_2.png,img_92_3.png): 0.386
# (img_92_2.png,img_92_4.png): 0.192
# (img_92_2.png,img_92_5.png): 0.096
# (img_92_2.png,img_92_6.png): 0.017
# (img_92_2.png,img_92_7.png): 0.015
# (img_92_2.png,img_92_8.png): 0.023
# (img_92_2.png,img_92_9.png): 0.039
# (img_92_3.png,img_92_4.png): 0.217
# (img_92_3.png,img_92_5.png): 0.322
# (img_92_3.png,img_92_6.png): 0.366
# (img_92_3.png,img_92_7.png): 0.365
# (img_92_3.png,img_92_8.png): 0.364
# (img_92_3.png,img_92_9.png): 0.346
# (img_92_4.png,img_92_5.png): 0.153
# (img_92_4.png,img_92_6.png): 0.158
# (img_92_4.png,img_92_7.png): 0.162
# (img_92_4.png,img_92_8.png): 0.192
# (img_92_4.png,img_92_9.png): 0.135
# (img_92_5.png,img_92_6.png): 0.070
# (img_92_5.png,img_92_7.png): 0.065
# (img_92_5.png,img_92_8.png): 0.059
# (img_92_5.png,img_92_9.png): 0.048
# (img_92_6.png,img_92_7.png): 0.003
# (img_92_6.png,img_92_8.png): 0.030
# (img_92_6.png,img_92_9.png): 0.011
# (img_92_7.png,img_92_8.png): 0.021
# (img_92_7.png,img_92_9.png): 0.010
# (img_92_8.png,img_92_9.png): 0.038
# Avg: 0.11844 +/- 0.01847
# (img_93_0.png,img_93_1.png): 0.122
# (img_93_0.png,img_93_2.png): 0.091
# (img_93_0.png,img_93_3.png): 0.167
# (img_93_0.png,img_93_4.png): 0.177
# (img_93_0.png,img_93_5.png): 0.070
# (img_93_0.png,img_93_6.png): 0.123
# (img_93_0.png,img_93_7.png): 0.034
# (img_93_0.png,img_93_8.png): 0.008
# (img_93_0.png,img_93_9.png): 0.143
# (img_93_1.png,img_93_2.png): 0.139
# (img_93_1.png,img_93_3.png): 0.026
# (img_93_1.png,img_93_4.png): 0.068
# (img_93_1.png,img_93_5.png): 0.161
# (img_93_1.png,img_93_6.png): 0.208
# (img_93_1.png,img_93_7.png): 0.116
# (img_93_1.png,img_93_8.png): 0.118
# (img_93_1.png,img_93_9.png): 0.171
# (img_93_2.png,img_93_3.png): 0.182
# (img_93_2.png,img_93_4.png): 0.242
# (img_93_2.png,img_93_5.png): 0.134
# (img_93_2.png,img_93_6.png): 0.188
# (img_93_2.png,img_93_7.png): 0.092
# (img_93_2.png,img_93_8.png): 0.088
# (img_93_2.png,img_93_9.png): 0.019
# (img_93_3.png,img_93_4.png): 0.066
# (img_93_3.png,img_93_5.png): 0.189
# (img_93_3.png,img_93_6.png): 0.232
# (img_93_3.png,img_93_7.png): 0.170
# (img_93_3.png,img_93_8.png): 0.168
# (img_93_3.png,img_93_9.png): 0.206
# (img_93_4.png,img_93_5.png): 0.208
# (img_93_4.png,img_93_6.png): 0.241
# (img_93_4.png,img_93_7.png): 0.179
# (img_93_4.png,img_93_8.png): 0.175
# (img_93_4.png,img_93_9.png): 0.277
# (img_93_5.png,img_93_6.png): 0.038
# (img_93_5.png,img_93_7.png): 0.136
# (img_93_5.png,img_93_8.png): 0.101
# (img_93_5.png,img_93_9.png): 0.162
# (img_93_6.png,img_93_7.png): 0.185
# (img_93_6.png,img_93_8.png): 0.154
# (img_93_6.png,img_93_9.png): 0.212
# (img_93_7.png,img_93_8.png): 0.013
# (img_93_7.png,img_93_9.png): 0.147
# (img_93_8.png,img_93_9.png): 0.144
# Avg: 0.13977 +/- 0.00975
# (img_94_0.png,img_94_1.png): 0.112
# (img_94_0.png,img_94_2.png): 0.200
# (img_94_0.png,img_94_3.png): 0.067
# (img_94_0.png,img_94_4.png): 0.272
# (img_94_0.png,img_94_5.png): 0.087
# (img_94_0.png,img_94_6.png): 0.060
# (img_94_0.png,img_94_7.png): 0.036
# (img_94_0.png,img_94_8.png): 0.133
# (img_94_0.png,img_94_9.png): 0.058
# (img_94_1.png,img_94_2.png): 0.075
# (img_94_1.png,img_94_3.png): 0.194
# (img_94_1.png,img_94_4.png): 0.182
# (img_94_1.png,img_94_5.png): 0.115
# (img_94_1.png,img_94_6.png): 0.167
# (img_94_1.png,img_94_7.png): 0.047
# (img_94_1.png,img_94_8.png): 0.125
# (img_94_1.png,img_94_9.png): 0.209
# (img_94_2.png,img_94_3.png): 0.256
# (img_94_2.png,img_94_4.png): 0.133
# (img_94_2.png,img_94_5.png): 0.160
# (img_94_2.png,img_94_6.png): 0.229
# (img_94_2.png,img_94_7.png): 0.140
# (img_94_2.png,img_94_8.png): 0.136
# (img_94_2.png,img_94_9.png): 0.277
# (img_94_3.png,img_94_4.png): 0.312
# (img_94_3.png,img_94_5.png): 0.084
# (img_94_3.png,img_94_6.png): 0.011
# (img_94_3.png,img_94_7.png): 0.114
# (img_94_3.png,img_94_8.png): 0.129
# (img_94_3.png,img_94_9.png): 0.033
# (img_94_4.png,img_94_5.png): 0.247
# (img_94_4.png,img_94_6.png): 0.295
# (img_94_4.png,img_94_7.png): 0.230
# (img_94_4.png,img_94_8.png): 0.234
# (img_94_4.png,img_94_9.png): 0.331
# (img_94_5.png,img_94_6.png): 0.050
# (img_94_5.png,img_94_7.png): 0.072
# (img_94_5.png,img_94_8.png): 0.025
# (img_94_5.png,img_94_9.png): 0.119
# (img_94_6.png,img_94_7.png): 0.089
# (img_94_6.png,img_94_8.png): 0.095
# (img_94_6.png,img_94_9.png): 0.047
# (img_94_7.png,img_94_8.png): 0.106
# (img_94_7.png,img_94_9.png): 0.125
# (img_94_8.png,img_94_9.png): 0.165
# Avg: 0.14185 +/- 0.01239
# (img_95_0.png,img_95_1.png): 0.266
# (img_95_0.png,img_95_2.png): 0.080
# (img_95_0.png,img_95_3.png): 0.216
# (img_95_0.png,img_95_4.png): 0.045
# (img_95_0.png,img_95_5.png): 0.122
# (img_95_0.png,img_95_6.png): 0.019
# (img_95_0.png,img_95_7.png): 0.090
# (img_95_0.png,img_95_8.png): 0.097
# (img_95_0.png,img_95_9.png): 0.048
# (img_95_1.png,img_95_2.png): 0.283
# (img_95_1.png,img_95_3.png): 0.296
# (img_95_1.png,img_95_4.png): 0.258
# (img_95_1.png,img_95_5.png): 0.138
# (img_95_1.png,img_95_6.png): 0.239
# (img_95_1.png,img_95_7.png): 0.305
# (img_95_1.png,img_95_8.png): 0.158
# (img_95_1.png,img_95_9.png): 0.242
# (img_95_2.png,img_95_3.png): 0.285
# (img_95_2.png,img_95_4.png): 0.020
# (img_95_2.png,img_95_5.png): 0.156
# (img_95_2.png,img_95_6.png): 0.058
# (img_95_2.png,img_95_7.png): 0.021
# (img_95_2.png,img_95_8.png): 0.150
# (img_95_2.png,img_95_9.png): 0.035
# (img_95_3.png,img_95_4.png): 0.255
# (img_95_3.png,img_95_5.png): 0.214
# (img_95_3.png,img_95_6.png): 0.220
# (img_95_3.png,img_95_7.png): 0.301
# (img_95_3.png,img_95_8.png): 0.199
# (img_95_3.png,img_95_9.png): 0.243
# (img_95_4.png,img_95_5.png): 0.118
# (img_95_4.png,img_95_6.png): 0.020
# (img_95_4.png,img_95_7.png): 0.039
# (img_95_4.png,img_95_8.png): 0.108
# (img_95_4.png,img_95_9.png): 0.008
# (img_95_5.png,img_95_6.png): 0.088
# (img_95_5.png,img_95_7.png): 0.186
# (img_95_5.png,img_95_8.png): 0.014
# (img_95_5.png,img_95_9.png): 0.094
# (img_95_6.png,img_95_7.png): 0.082
# (img_95_6.png,img_95_8.png): 0.071
# (img_95_6.png,img_95_9.png): 0.013
# (img_95_7.png,img_95_8.png): 0.179
# (img_95_7.png,img_95_9.png): 0.066
# (img_95_8.png,img_95_9.png): 0.085
# Avg: 0.13849 +/- 0.01408
# (img_96_0.png,img_96_1.png): 0.035
# (img_96_0.png,img_96_2.png): 0.093
# (img_96_0.png,img_96_3.png): 0.182
# (img_96_0.png,img_96_4.png): 0.093
# (img_96_0.png,img_96_5.png): 0.035
# (img_96_0.png,img_96_6.png): 0.014
# (img_96_0.png,img_96_7.png): 0.062
# (img_96_0.png,img_96_8.png): 0.080
# (img_96_0.png,img_96_9.png): 0.012
# (img_96_1.png,img_96_2.png): 0.040
# (img_96_1.png,img_96_3.png): 0.211
# (img_96_1.png,img_96_4.png): 0.135
# (img_96_1.png,img_96_5.png): 0.093
# (img_96_1.png,img_96_6.png): 0.027
# (img_96_1.png,img_96_7.png): 0.014
# (img_96_1.png,img_96_8.png): 0.030
# (img_96_1.png,img_96_9.png): 0.034
# (img_96_2.png,img_96_3.png): 0.215
# (img_96_2.png,img_96_4.png): 0.174
# (img_96_2.png,img_96_5.png): 0.154
# (img_96_2.png,img_96_6.png): 0.080
# (img_96_2.png,img_96_7.png): 0.017
# (img_96_2.png,img_96_8.png): 0.021
# (img_96_2.png,img_96_9.png): 0.088
# (img_96_3.png,img_96_4.png): 0.197
# (img_96_3.png,img_96_5.png): 0.193
# (img_96_3.png,img_96_6.png): 0.204
# (img_96_3.png,img_96_7.png): 0.213
# (img_96_3.png,img_96_8.png): 0.224
# (img_96_3.png,img_96_9.png): 0.177
# (img_96_4.png,img_96_5.png): 0.053
# (img_96_4.png,img_96_6.png): 0.085
# (img_96_4.png,img_96_7.png): 0.161
# (img_96_4.png,img_96_8.png): 0.159
# (img_96_4.png,img_96_9.png): 0.119
# (img_96_5.png,img_96_6.png): 0.045
# (img_96_5.png,img_96_7.png): 0.126
# (img_96_5.png,img_96_8.png): 0.138
# (img_96_5.png,img_96_9.png): 0.056
# (img_96_6.png,img_96_7.png): 0.057
# (img_96_6.png,img_96_8.png): 0.059
# (img_96_6.png,img_96_9.png): 0.033
# (img_96_7.png,img_96_8.png): 0.029
# (img_96_7.png,img_96_9.png): 0.053
# (img_96_8.png,img_96_9.png): 0.084
# Avg: 0.09786 +/- 0.00999
# (img_97_0.png,img_97_1.png): 0.102
# (img_97_0.png,img_97_2.png): 0.279
# (img_97_0.png,img_97_3.png): 0.196
# (img_97_0.png,img_97_4.png): 0.062
# (img_97_0.png,img_97_5.png): 0.055
# (img_97_0.png,img_97_6.png): 0.061
# (img_97_0.png,img_97_7.png): 0.074
# (img_97_0.png,img_97_8.png): 0.260
# (img_97_0.png,img_97_9.png): 0.109
# (img_97_1.png,img_97_2.png): 0.231
# (img_97_1.png,img_97_3.png): 0.119
# (img_97_1.png,img_97_4.png): 0.158
# (img_97_1.png,img_97_5.png): 0.032
# (img_97_1.png,img_97_6.png): 0.073
# (img_97_1.png,img_97_7.png): 0.176
# (img_97_1.png,img_97_8.png): 0.212
# (img_97_1.png,img_97_9.png): 0.088
# (img_97_2.png,img_97_3.png): 0.143
# (img_97_2.png,img_97_4.png): 0.293
# (img_97_2.png,img_97_5.png): 0.253
# (img_97_2.png,img_97_6.png): 0.272
# (img_97_2.png,img_97_7.png): 0.303
# (img_97_2.png,img_97_8.png): 0.090
# (img_97_2.png,img_97_9.png): 0.276
# (img_97_3.png,img_97_4.png): 0.248
# (img_97_3.png,img_97_5.png): 0.161
# (img_97_3.png,img_97_6.png): 0.203
# (img_97_3.png,img_97_7.png): 0.262
# (img_97_3.png,img_97_8.png): 0.182
# (img_97_3.png,img_97_9.png): 0.215
# (img_97_4.png,img_97_5.png): 0.106
# (img_97_4.png,img_97_6.png): 0.069
# (img_97_4.png,img_97_7.png): 0.004
# (img_97_4.png,img_97_8.png): 0.247
# (img_97_4.png,img_97_9.png): 0.089
# (img_97_5.png,img_97_6.png): 0.023
# (img_97_5.png,img_97_7.png): 0.124
# (img_97_5.png,img_97_8.png): 0.229
# (img_97_5.png,img_97_9.png): 0.050
# (img_97_6.png,img_97_7.png): 0.086
# (img_97_6.png,img_97_8.png): 0.233
# (img_97_6.png,img_97_9.png): 0.020
# (img_97_7.png,img_97_8.png): 0.257
# (img_97_7.png,img_97_9.png): 0.105
# (img_97_8.png,img_97_9.png): 0.226
# Avg: 0.15678 +/- 0.01298
# (img_98_0.png,img_98_1.png): 0.420
# (img_98_0.png,img_98_2.png): 0.460
# (img_98_0.png,img_98_3.png): 0.203
# (img_98_0.png,img_98_4.png): 0.396
# (img_98_0.png,img_98_5.png): 0.244
# (img_98_0.png,img_98_6.png): 0.150
# (img_98_0.png,img_98_7.png): 0.034
# (img_98_0.png,img_98_8.png): 0.006
# (img_98_0.png,img_98_9.png): 0.007
# (img_98_1.png,img_98_2.png): 0.120
# (img_98_1.png,img_98_3.png): 0.374
# (img_98_1.png,img_98_4.png): 0.327
# (img_98_1.png,img_98_5.png): 0.463
# (img_98_1.png,img_98_6.png): 0.419
# (img_98_1.png,img_98_7.png): 0.392
# (img_98_1.png,img_98_8.png): 0.409
# (img_98_1.png,img_98_9.png): 0.426
# (img_98_2.png,img_98_3.png): 0.415
# (img_98_2.png,img_98_4.png): 0.289
# (img_98_2.png,img_98_5.png): 0.488
# (img_98_2.png,img_98_6.png): 0.450
# (img_98_2.png,img_98_7.png): 0.430
# (img_98_2.png,img_98_8.png): 0.449
# (img_98_2.png,img_98_9.png): 0.466
# (img_98_3.png,img_98_4.png): 0.354
# (img_98_3.png,img_98_5.png): 0.234
# (img_98_3.png,img_98_6.png): 0.123
# (img_98_3.png,img_98_7.png): 0.178
# (img_98_3.png,img_98_8.png): 0.197
# (img_98_3.png,img_98_9.png): 0.213
# (img_98_4.png,img_98_5.png): 0.295
# (img_98_4.png,img_98_6.png): 0.357
# (img_98_4.png,img_98_7.png): 0.391
# (img_98_4.png,img_98_8.png): 0.393
# (img_98_4.png,img_98_9.png): 0.399
# (img_98_5.png,img_98_6.png): 0.124
# (img_98_5.png,img_98_7.png): 0.231
# (img_98_5.png,img_98_8.png): 0.238
# (img_98_5.png,img_98_9.png): 0.244
# (img_98_6.png,img_98_7.png): 0.127
# (img_98_6.png,img_98_8.png): 0.144
# (img_98_6.png,img_98_9.png): 0.158
# (img_98_7.png,img_98_8.png): 0.020
# (img_98_7.png,img_98_9.png): 0.047
# (img_98_8.png,img_98_9.png): 0.013
# Avg: 0.27370 +/- 0.02215
# (img_99_0.png,img_99_1.png): 0.131
# (img_99_0.png,img_99_2.png): 0.235
# (img_99_0.png,img_99_3.png): 0.245
# (img_99_0.png,img_99_4.png): 0.156
# (img_99_0.png,img_99_5.png): 0.257
# (img_99_0.png,img_99_6.png): 0.222
# (img_99_0.png,img_99_7.png): 0.231
# (img_99_0.png,img_99_8.png): 0.252
# (img_99_0.png,img_99_9.png): 0.210
# (img_99_1.png,img_99_2.png): 0.106
# (img_99_1.png,img_99_3.png): 0.112
# (img_99_1.png,img_99_4.png): 0.029
# (img_99_1.png,img_99_5.png): 0.134
# (img_99_1.png,img_99_6.png): 0.132
# (img_99_1.png,img_99_7.png): 0.113
# (img_99_1.png,img_99_8.png): 0.130
# (img_99_1.png,img_99_9.png): 0.275
# (img_99_2.png,img_99_3.png): 0.007
# (img_99_2.png,img_99_4.png): 0.097
# (img_99_2.png,img_99_5.png): 0.013
# (img_99_2.png,img_99_6.png): 0.102
# (img_99_2.png,img_99_7.png): 0.018
# (img_99_2.png,img_99_8.png): 0.012
# (img_99_2.png,img_99_9.png): 0.337
# (img_99_3.png,img_99_4.png): 0.111
# (img_99_3.png,img_99_5.png): 0.006
# (img_99_3.png,img_99_6.png): 0.126
# (img_99_3.png,img_99_7.png): 0.037
# (img_99_3.png,img_99_8.png): 0.006
# (img_99_3.png,img_99_9.png): 0.344
# (img_99_4.png,img_99_5.png): 0.131
# (img_99_4.png,img_99_6.png): 0.076
# (img_99_4.png,img_99_7.png): 0.091
# (img_99_4.png,img_99_8.png): 0.126
# (img_99_4.png,img_99_9.png): 0.284
# (img_99_5.png,img_99_6.png): 0.133
# (img_99_5.png,img_99_7.png): 0.040
# (img_99_5.png,img_99_8.png): 0.002
# (img_99_5.png,img_99_9.png): 0.351
# (img_99_6.png,img_99_7.png): 0.073
# (img_99_6.png,img_99_8.png): 0.131
# (img_99_6.png,img_99_9.png): 0.312
# (img_99_7.png,img_99_8.png): 0.037
# (img_99_7.png,img_99_9.png): 0.330
# (img_99_8.png,img_99_9.png): 0.347
# Avg: 0.14781 +/- 0.01602
# (img_100_0.png,img_100_1.png): 0.163
# (img_100_0.png,img_100_2.png): 0.162
# (img_100_0.png,img_100_3.png): 0.074
# (img_100_0.png,img_100_4.png): 0.130
# (img_100_0.png,img_100_5.png): 0.164
# (img_100_0.png,img_100_6.png): 0.053
# (img_100_0.png,img_100_7.png): 0.169
# (img_100_0.png,img_100_8.png): 0.160
# (img_100_0.png,img_100_9.png): 0.153
# (img_100_1.png,img_100_2.png): 0.009
# (img_100_1.png,img_100_3.png): 0.081
# (img_100_1.png,img_100_4.png): 0.021
# (img_100_1.png,img_100_5.png): 0.002
# (img_100_1.png,img_100_6.png): 0.095
# (img_100_1.png,img_100_7.png): 0.071
# (img_100_1.png,img_100_8.png): 0.014
# (img_100_1.png,img_100_9.png): 0.007
# (img_100_2.png,img_100_3.png): 0.077
# (img_100_2.png,img_100_4.png): 0.030
# (img_100_2.png,img_100_5.png): 0.003
# (img_100_2.png,img_100_6.png): 0.096
# (img_100_2.png,img_100_7.png): 0.072
# (img_100_2.png,img_100_8.png): 0.034
# (img_100_2.png,img_100_9.png): 0.012
# (img_100_3.png,img_100_4.png): 0.045
# (img_100_3.png,img_100_5.png): 0.079
# (img_100_3.png,img_100_6.png): 0.008
# (img_100_3.png,img_100_7.png): 0.123
# (img_100_3.png,img_100_8.png): 0.091
# (img_100_3.png,img_100_9.png): 0.066
# (img_100_4.png,img_100_5.png): 0.024
# (img_100_4.png,img_100_6.png): 0.054
# (img_100_4.png,img_100_7.png): 0.095
# (img_100_4.png,img_100_8.png): 0.024
# (img_100_4.png,img_100_9.png): 0.011
# (img_100_5.png,img_100_6.png): 0.096
# (img_100_5.png,img_100_7.png): 0.071
# (img_100_5.png,img_100_8.png): 0.021
# (img_100_5.png,img_100_9.png): 0.007
# (img_100_6.png,img_100_7.png): 0.135
# (img_100_6.png,img_100_8.png): 0.098
# (img_100_6.png,img_100_9.png): 0.080
# (img_100_7.png,img_100_8.png): 0.075
# (img_100_7.png,img_100_9.png): 0.081
# (img_100_8.png,img_100_9.png): 0.018
# Avg: 0.07005 +/- 0.00758
# (img_101_0.png,img_101_1.png): 0.048
# (img_101_0.png,img_101_2.png): 0.086
# (img_101_0.png,img_101_3.png): 0.367
# (img_101_0.png,img_101_4.png): 0.055
# (img_101_0.png,img_101_5.png): 0.303
# (img_101_0.png,img_101_6.png): 0.010
# (img_101_0.png,img_101_7.png): 0.137
# (img_101_0.png,img_101_8.png): 0.287
# (img_101_0.png,img_101_9.png): 0.304
# (img_101_1.png,img_101_2.png): 0.056
# (img_101_1.png,img_101_3.png): 0.332
# (img_101_1.png,img_101_4.png): 0.015
# (img_101_1.png,img_101_5.png): 0.293
# (img_101_1.png,img_101_6.png): 0.040
# (img_101_1.png,img_101_7.png): 0.096
# (img_101_1.png,img_101_8.png): 0.288
# (img_101_1.png,img_101_9.png): 0.308
# (img_101_2.png,img_101_3.png): 0.309
# (img_101_2.png,img_101_4.png): 0.047
# (img_101_2.png,img_101_5.png): 0.221
# (img_101_2.png,img_101_6.png): 0.099
# (img_101_2.png,img_101_7.png): 0.034
# (img_101_2.png,img_101_8.png): 0.226
# (img_101_2.png,img_101_9.png): 0.251
# (img_101_3.png,img_101_4.png): 0.322
# (img_101_3.png,img_101_5.png): 0.205
# (img_101_3.png,img_101_6.png): 0.368
# (img_101_3.png,img_101_7.png): 0.257
# (img_101_3.png,img_101_8.png): 0.396
# (img_101_3.png,img_101_9.png): 0.418
# (img_101_4.png,img_101_5.png): 0.285
# (img_101_4.png,img_101_6.png): 0.048
# (img_101_4.png,img_101_7.png): 0.085
# (img_101_4.png,img_101_8.png): 0.288
# (img_101_4.png,img_101_9.png): 0.309
# (img_101_5.png,img_101_6.png): 0.319
# (img_101_5.png,img_101_7.png): 0.174
# (img_101_5.png,img_101_8.png): 0.235
# (img_101_5.png,img_101_9.png): 0.263
# (img_101_6.png,img_101_7.png): 0.146
# (img_101_6.png,img_101_8.png): 0.303
# (img_101_6.png,img_101_9.png): 0.320
# (img_101_7.png,img_101_8.png): 0.241
# (img_101_7.png,img_101_9.png): 0.268
# (img_101_8.png,img_101_9.png): 0.007
# Avg: 0.21044 +/- 0.01792
# (img_102_0.png,img_102_1.png): 0.367
# (img_102_0.png,img_102_2.png): 0.193
# (img_102_0.png,img_102_3.png): 0.216
# (img_102_0.png,img_102_4.png): 0.200
# (img_102_0.png,img_102_5.png): 0.238
# (img_102_0.png,img_102_6.png): 0.229
# (img_102_0.png,img_102_7.png): 0.158
# (img_102_0.png,img_102_8.png): 0.201
# (img_102_0.png,img_102_9.png): 0.134
# (img_102_1.png,img_102_2.png): 0.309
# (img_102_1.png,img_102_3.png): 0.306
# (img_102_1.png,img_102_4.png): 0.283
# (img_102_1.png,img_102_5.png): 0.296
# (img_102_1.png,img_102_6.png): 0.291
# (img_102_1.png,img_102_7.png): 0.324
# (img_102_1.png,img_102_8.png): 0.511
# (img_102_1.png,img_102_9.png): 0.290
# (img_102_2.png,img_102_3.png): 0.009
# (img_102_2.png,img_102_4.png): 0.017
# (img_102_2.png,img_102_5.png): 0.048
# (img_102_2.png,img_102_6.png): 0.029
# (img_102_2.png,img_102_7.png): 0.024
# (img_102_2.png,img_102_8.png): 0.332
# (img_102_2.png,img_102_9.png): 0.070
# (img_102_3.png,img_102_4.png): 0.016
# (img_102_3.png,img_102_5.png): 0.032
# (img_102_3.png,img_102_6.png): 0.014
# (img_102_3.png,img_102_7.png): 0.043
# (img_102_3.png,img_102_8.png): 0.347
# (img_102_3.png,img_102_9.png): 0.088
# (img_102_4.png,img_102_5.png): 0.030
# (img_102_4.png,img_102_6.png): 0.014
# (img_102_4.png,img_102_7.png): 0.038
# (img_102_4.png,img_102_8.png): 0.345
# (img_102_4.png,img_102_9.png): 0.061
# (img_102_5.png,img_102_6.png): 0.010
# (img_102_5.png,img_102_7.png): 0.081
# (img_102_5.png,img_102_8.png): 0.373
# (img_102_5.png,img_102_9.png): 0.114
# (img_102_6.png,img_102_7.png): 0.063
# (img_102_6.png,img_102_8.png): 0.364
# (img_102_6.png,img_102_9.png): 0.099
# (img_102_7.png,img_102_8.png): 0.306
# (img_102_7.png,img_102_9.png): 0.038
# (img_102_8.png,img_102_9.png): 0.303
# Avg: 0.17450 +/- 0.02037
# (img_103_0.png,img_103_1.png): 0.220
# (img_103_0.png,img_103_2.png): 0.154
# (img_103_0.png,img_103_3.png): 0.165
# (img_103_0.png,img_103_4.png): 0.285
# (img_103_0.png,img_103_5.png): 0.160
# (img_103_0.png,img_103_6.png): 0.098
# (img_103_0.png,img_103_7.png): 0.094
# (img_103_0.png,img_103_8.png): 0.170
# (img_103_0.png,img_103_9.png): 0.182
# (img_103_1.png,img_103_2.png): 0.045
# (img_103_1.png,img_103_3.png): 0.251
# (img_103_1.png,img_103_4.png): 0.254
# (img_103_1.png,img_103_5.png): 0.032
# (img_103_1.png,img_103_6.png): 0.104
# (img_103_1.png,img_103_7.png): 0.107
# (img_103_1.png,img_103_8.png): 0.030
# (img_103_1.png,img_103_9.png): 0.073
# (img_103_2.png,img_103_3.png): 0.163
# (img_103_2.png,img_103_4.png): 0.186
# (img_103_2.png,img_103_5.png): 0.005
# (img_103_2.png,img_103_6.png): 0.030
# (img_103_2.png,img_103_7.png): 0.033
# (img_103_2.png,img_103_8.png): 0.036
# (img_103_2.png,img_103_9.png): 0.024
# (img_103_3.png,img_103_4.png): 0.099
# (img_103_3.png,img_103_5.png): 0.186
# (img_103_3.png,img_103_6.png): 0.120
# (img_103_3.png,img_103_7.png): 0.118
# (img_103_3.png,img_103_8.png): 0.223
# (img_103_3.png,img_103_9.png): 0.126
# (img_103_4.png,img_103_5.png): 0.212
# (img_103_4.png,img_103_6.png): 0.183
# (img_103_4.png,img_103_7.png): 0.184
# (img_103_4.png,img_103_8.png): 0.252
# (img_103_4.png,img_103_9.png): 0.124
# (img_103_5.png,img_103_6.png): 0.040
# (img_103_5.png,img_103_7.png): 0.043
# (img_103_5.png,img_103_8.png): 0.026
# (img_103_5.png,img_103_9.png): 0.035
# (img_103_6.png,img_103_7.png): 0.001
# (img_103_6.png,img_103_8.png): 0.063
# (img_103_6.png,img_103_9.png): 0.051
# (img_103_7.png,img_103_8.png): 0.064
# (img_103_7.png,img_103_9.png): 0.054
# (img_103_8.png,img_103_9.png): 0.082
# Avg: 0.11526 +/- 0.01151
# (img_104_0.png,img_104_1.png): 0.040
# (img_104_0.png,img_104_2.png): 0.032
# (img_104_0.png,img_104_3.png): 0.106
# (img_104_0.png,img_104_4.png): 0.039
# (img_104_0.png,img_104_5.png): 0.114
# (img_104_0.png,img_104_6.png): 0.366
# (img_104_0.png,img_104_7.png): 0.340
# (img_104_0.png,img_104_8.png): 0.040
# (img_104_0.png,img_104_9.png): 0.054
# (img_104_1.png,img_104_2.png): 0.032
# (img_104_1.png,img_104_3.png): 0.064
# (img_104_1.png,img_104_4.png): 0.033
# (img_104_1.png,img_104_5.png): 0.066
# (img_104_1.png,img_104_6.png): 0.341
# (img_104_1.png,img_104_7.png): 0.301
# (img_104_1.png,img_104_8.png): 0.024
# (img_104_1.png,img_104_9.png): 0.013
# (img_104_2.png,img_104_3.png): 0.051
# (img_104_2.png,img_104_4.png): 0.001
# (img_104_2.png,img_104_5.png): 0.062
# (img_104_2.png,img_104_6.png): 0.340
# (img_104_2.png,img_104_7.png): 0.321
# (img_104_2.png,img_104_8.png): 0.003
# (img_104_2.png,img_104_9.png): 0.020
# (img_104_3.png,img_104_4.png): 0.042
# (img_104_3.png,img_104_5.png): 0.003
# (img_104_3.png,img_104_6.png): 0.315
# (img_104_3.png,img_104_7.png): 0.288
# (img_104_3.png,img_104_8.png): 0.038
# (img_104_3.png,img_104_9.png): 0.032
# (img_104_4.png,img_104_5.png): 0.053
# (img_104_4.png,img_104_6.png): 0.336
# (img_104_4.png,img_104_7.png): 0.317
# (img_104_4.png,img_104_8.png): 0.002
# (img_104_4.png,img_104_9.png): 0.017
# (img_104_5.png,img_104_6.png): 0.308
# (img_104_5.png,img_104_7.png): 0.277
# (img_104_5.png,img_104_8.png): 0.047
# (img_104_5.png,img_104_9.png): 0.036
# (img_104_6.png,img_104_7.png): 0.218
# (img_104_6.png,img_104_8.png): 0.334
# (img_104_6.png,img_104_9.png): 0.331
# (img_104_7.png,img_104_8.png): 0.312
# (img_104_7.png,img_104_9.png): 0.298
# (img_104_8.png,img_104_9.png): 0.010
# Avg: 0.14261 +/- 0.02043
# (img_105_0.png,img_105_1.png): 0.176
# (img_105_0.png,img_105_2.png): 0.341
# (img_105_0.png,img_105_3.png): 0.019
# (img_105_0.png,img_105_4.png): 0.046
# (img_105_0.png,img_105_5.png): 0.096
# (img_105_0.png,img_105_6.png): 0.203
# (img_105_0.png,img_105_7.png): 0.124
# (img_105_0.png,img_105_8.png): 0.054
# (img_105_0.png,img_105_9.png): 0.280
# (img_105_1.png,img_105_2.png): 0.254
# (img_105_1.png,img_105_3.png): 0.166
# (img_105_1.png,img_105_4.png): 0.224
# (img_105_1.png,img_105_5.png): 0.166
# (img_105_1.png,img_105_6.png): 0.094
# (img_105_1.png,img_105_7.png): 0.131
# (img_105_1.png,img_105_8.png): 0.141
# (img_105_1.png,img_105_9.png): 0.176
# (img_105_2.png,img_105_3.png): 0.338
# (img_105_2.png,img_105_4.png): 0.373
# (img_105_2.png,img_105_5.png): 0.347
# (img_105_2.png,img_105_6.png): 0.232
# (img_105_2.png,img_105_7.png): 0.343
# (img_105_2.png,img_105_8.png): 0.320
# (img_105_2.png,img_105_9.png): 0.220
# (img_105_3.png,img_105_4.png): 0.082
# (img_105_3.png,img_105_5.png): 0.053
# (img_105_3.png,img_105_6.png): 0.215
# (img_105_3.png,img_105_7.png): 0.085
# (img_105_3.png,img_105_8.png): 0.081
# (img_105_3.png,img_105_9.png): 0.291
# (img_105_4.png,img_105_5.png): 0.163
# (img_105_4.png,img_105_6.png): 0.229
# (img_105_4.png,img_105_7.png): 0.191
# (img_105_4.png,img_105_8.png): 0.091
# (img_105_4.png,img_105_9.png): 0.297
# (img_105_5.png,img_105_6.png): 0.253
# (img_105_5.png,img_105_7.png): 0.023
# (img_105_5.png,img_105_8.png): 0.134
# (img_105_5.png,img_105_9.png): 0.328
# (img_105_6.png,img_105_7.png): 0.239
# (img_105_6.png,img_105_8.png): 0.151
# (img_105_6.png,img_105_9.png): 0.054
# (img_105_7.png,img_105_8.png): 0.142
# (img_105_7.png,img_105_9.png): 0.316
# (img_105_8.png,img_105_9.png): 0.238
# Avg: 0.18922 +/- 0.01478
# (img_106_0.png,img_106_1.png): 0.093
# (img_106_0.png,img_106_2.png): 0.160
# (img_106_0.png,img_106_3.png): 0.087
# (img_106_0.png,img_106_4.png): 0.089
# (img_106_0.png,img_106_5.png): 0.067
# (img_106_0.png,img_106_6.png): 0.091
# (img_106_0.png,img_106_7.png): 0.095
# (img_106_0.png,img_106_8.png): 0.249
# (img_106_0.png,img_106_9.png): 0.110
# (img_106_1.png,img_106_2.png): 0.099
# (img_106_1.png,img_106_3.png): 0.012
# (img_106_1.png,img_106_4.png): 0.027
# (img_106_1.png,img_106_5.png): 0.095
# (img_106_1.png,img_106_6.png): 0.036
# (img_106_1.png,img_106_7.png): 0.015
# (img_106_1.png,img_106_8.png): 0.204
# (img_106_1.png,img_106_9.png): 0.053
# (img_106_2.png,img_106_3.png): 0.132
# (img_106_2.png,img_106_4.png): 0.146
# (img_106_2.png,img_106_5.png): 0.177
# (img_106_2.png,img_106_6.png): 0.149
# (img_106_2.png,img_106_7.png): 0.077
# (img_106_2.png,img_106_8.png): 0.166
# (img_106_2.png,img_106_9.png): 0.052
# (img_106_3.png,img_106_4.png): 0.007
# (img_106_3.png,img_106_5.png): 0.077
# (img_106_3.png,img_106_6.png): 0.015
# (img_106_3.png,img_106_7.png): 0.028
# (img_106_3.png,img_106_8.png): 0.226
# (img_106_3.png,img_106_9.png): 0.071
# (img_106_4.png,img_106_5.png): 0.067
# (img_106_4.png,img_106_6.png): 0.004
# (img_106_4.png,img_106_7.png): 0.037
# (img_106_4.png,img_106_8.png): 0.243
# (img_106_4.png,img_106_9.png): 0.076
# (img_106_5.png,img_106_6.png): 0.064
# (img_106_5.png,img_106_7.png): 0.093
# (img_106_5.png,img_106_8.png): 0.261
# (img_106_5.png,img_106_9.png): 0.120
# (img_106_6.png,img_106_7.png): 0.040
# (img_106_6.png,img_106_8.png): 0.251
# (img_106_6.png,img_106_9.png): 0.076
# (img_106_7.png,img_106_8.png): 0.206
# (img_106_7.png,img_106_9.png): 0.026
# (img_106_8.png,img_106_9.png): 0.204
# Avg: 0.10384 +/- 0.01086
# (img_107_0.png,img_107_1.png): 0.113
# (img_107_0.png,img_107_2.png): 0.291
# (img_107_0.png,img_107_3.png): 0.310
# (img_107_0.png,img_107_4.png): 0.268
# (img_107_0.png,img_107_5.png): 0.292
# (img_107_0.png,img_107_6.png): 0.292
# (img_107_0.png,img_107_7.png): 0.309
# (img_107_0.png,img_107_8.png): 0.272
# (img_107_0.png,img_107_9.png): 0.265
# (img_107_1.png,img_107_2.png): 0.207
# (img_107_1.png,img_107_3.png): 0.231
# (img_107_1.png,img_107_4.png): 0.318
# (img_107_1.png,img_107_5.png): 0.224
# (img_107_1.png,img_107_6.png): 0.204
# (img_107_1.png,img_107_7.png): 0.230
# (img_107_1.png,img_107_8.png): 0.196
# (img_107_1.png,img_107_9.png): 0.186
# (img_107_2.png,img_107_3.png): 0.037
# (img_107_2.png,img_107_4.png): 0.356
# (img_107_2.png,img_107_5.png): 0.107
# (img_107_2.png,img_107_6.png): 0.024
# (img_107_2.png,img_107_7.png): 0.046
# (img_107_2.png,img_107_8.png): 0.032
# (img_107_2.png,img_107_9.png): 0.032
# (img_107_3.png,img_107_4.png): 0.346
# (img_107_3.png,img_107_5.png): 0.074
# (img_107_3.png,img_107_6.png): 0.086
# (img_107_3.png,img_107_7.png): 0.003
# (img_107_3.png,img_107_8.png): 0.052
# (img_107_3.png,img_107_9.png): 0.084
# (img_107_4.png,img_107_5.png): 0.300
# (img_107_4.png,img_107_6.png): 0.386
# (img_107_4.png,img_107_7.png): 0.338
# (img_107_4.png,img_107_8.png): 0.310
# (img_107_4.png,img_107_9.png): 0.331
# (img_107_5.png,img_107_6.png): 0.148
# (img_107_5.png,img_107_7.png): 0.063
# (img_107_5.png,img_107_8.png): 0.075
# (img_107_5.png,img_107_9.png): 0.110
# (img_107_6.png,img_107_7.png): 0.096
# (img_107_6.png,img_107_8.png): 0.067
# (img_107_6.png,img_107_9.png): 0.034
# (img_107_7.png,img_107_8.png): 0.053
# (img_107_7.png,img_107_9.png): 0.088
# (img_107_8.png,img_107_9.png): 0.021
# Avg: 0.17567 +/- 0.01744
# (img_108_0.png,img_108_1.png): 0.084
# (img_108_0.png,img_108_2.png): 0.005
# (img_108_0.png,img_108_3.png): 0.044
# (img_108_0.png,img_108_4.png): 0.182
# (img_108_0.png,img_108_5.png): 0.058
# (img_108_0.png,img_108_6.png): 0.289
# (img_108_0.png,img_108_7.png): 0.049
# (img_108_0.png,img_108_8.png): 0.021
# (img_108_0.png,img_108_9.png): 0.048
# (img_108_1.png,img_108_2.png): 0.080
# (img_108_1.png,img_108_3.png): 0.019
# (img_108_1.png,img_108_4.png): 0.062
# (img_108_1.png,img_108_5.png): 0.010
# (img_108_1.png,img_108_6.png): 0.228
# (img_108_1.png,img_108_7.png): 0.036
# (img_108_1.png,img_108_8.png): 0.071
# (img_108_1.png,img_108_9.png): 0.026
# (img_108_2.png,img_108_3.png): 0.039
# (img_108_2.png,img_108_4.png): 0.178
# (img_108_2.png,img_108_5.png): 0.052
# (img_108_2.png,img_108_6.png): 0.282
# (img_108_2.png,img_108_7.png): 0.037
# (img_108_2.png,img_108_8.png): 0.019
# (img_108_2.png,img_108_9.png): 0.040
# (img_108_3.png,img_108_4.png): 0.107
# (img_108_3.png,img_108_5.png): 0.003
# (img_108_3.png,img_108_6.png): 0.240
# (img_108_3.png,img_108_7.png): 0.013
# (img_108_3.png,img_108_8.png): 0.033
# (img_108_3.png,img_108_9.png): 0.006
# (img_108_4.png,img_108_5.png): 0.091
# (img_108_4.png,img_108_6.png): 0.202
# (img_108_4.png,img_108_7.png): 0.127
# (img_108_4.png,img_108_8.png): 0.166
# (img_108_4.png,img_108_9.png): 0.117
# (img_108_5.png,img_108_6.png): 0.234
# (img_108_5.png,img_108_7.png): 0.016
# (img_108_5.png,img_108_8.png): 0.044
# (img_108_5.png,img_108_9.png): 0.009
# (img_108_6.png,img_108_7.png): 0.238
# (img_108_6.png,img_108_8.png): 0.273
# (img_108_6.png,img_108_9.png): 0.237
# (img_108_7.png,img_108_8.png): 0.038
# (img_108_7.png,img_108_9.png): 0.004
# (img_108_8.png,img_108_9.png): 0.035
# Avg: 0.09317 +/- 0.01327
# (img_109_0.png,img_109_1.png): 0.019
# (img_109_0.png,img_109_2.png): 0.136
# (img_109_0.png,img_109_3.png): 0.087
# (img_109_0.png,img_109_4.png): 0.046
# (img_109_0.png,img_109_5.png): 0.020
# (img_109_0.png,img_109_6.png): 0.087
# (img_109_0.png,img_109_7.png): 0.217
# (img_109_0.png,img_109_8.png): 0.013
# (img_109_0.png,img_109_9.png): 0.183
# (img_109_1.png,img_109_2.png): 0.125
# (img_109_1.png,img_109_3.png): 0.084
# (img_109_1.png,img_109_4.png): 0.017
# (img_109_1.png,img_109_5.png): 0.002
# (img_109_1.png,img_109_6.png): 0.057
# (img_109_1.png,img_109_7.png): 0.216
# (img_109_1.png,img_109_8.png): 0.030
# (img_109_1.png,img_109_9.png): 0.166
# (img_109_2.png,img_109_3.png): 0.036
# (img_109_2.png,img_109_4.png): 0.092
# (img_109_2.png,img_109_5.png): 0.124
# (img_109_2.png,img_109_6.png): 0.062
# (img_109_2.png,img_109_7.png): 0.120
# (img_109_2.png,img_109_8.png): 0.165
# (img_109_2.png,img_109_9.png): 0.111
# (img_109_3.png,img_109_4.png): 0.059
# (img_109_3.png,img_109_5.png): 0.081
# (img_109_3.png,img_109_6.png): 0.051
# (img_109_3.png,img_109_7.png): 0.151
# (img_109_3.png,img_109_8.png): 0.116
# (img_109_3.png,img_109_9.png): 0.146
# (img_109_4.png,img_109_5.png): 0.014
# (img_109_4.png,img_109_6.png): 0.021
# (img_109_4.png,img_109_7.png): 0.201
# (img_109_4.png,img_109_8.png): 0.066
# (img_109_4.png,img_109_9.png): 0.149
# (img_109_5.png,img_109_6.png): 0.055
# (img_109_5.png,img_109_7.png): 0.215
# (img_109_5.png,img_109_8.png): 0.032
# (img_109_5.png,img_109_9.png): 0.169
# (img_109_6.png,img_109_7.png): 0.189
# (img_109_6.png,img_109_8.png): 0.112
# (img_109_6.png,img_109_9.png): 0.127
# (img_109_7.png,img_109_8.png): 0.231
# (img_109_7.png,img_109_9.png): 0.186
# (img_109_8.png,img_109_9.png): 0.202
# Avg: 0.10641 +/- 0.00998
# (img_110_0.png,img_110_1.png): 0.025
# (img_110_0.png,img_110_2.png): 0.005
# (img_110_0.png,img_110_3.png): 0.073
# (img_110_0.png,img_110_4.png): 0.037
# (img_110_0.png,img_110_5.png): 0.105
# (img_110_0.png,img_110_6.png): 0.150
# (img_110_0.png,img_110_7.png): 0.065
# (img_110_0.png,img_110_8.png): 0.079
# (img_110_0.png,img_110_9.png): 0.115
# (img_110_1.png,img_110_2.png): 0.032
# (img_110_1.png,img_110_3.png): 0.104
# (img_110_1.png,img_110_4.png): 0.080
# (img_110_1.png,img_110_5.png): 0.154
# (img_110_1.png,img_110_6.png): 0.137
# (img_110_1.png,img_110_7.png): 0.102
# (img_110_1.png,img_110_8.png): 0.130
# (img_110_1.png,img_110_9.png): 0.158
# (img_110_2.png,img_110_3.png): 0.061
# (img_110_2.png,img_110_4.png): 0.026
# (img_110_2.png,img_110_5.png): 0.092
# (img_110_2.png,img_110_6.png): 0.141
# (img_110_2.png,img_110_7.png): 0.067
# (img_110_2.png,img_110_8.png): 0.066
# (img_110_2.png,img_110_9.png): 0.101
# (img_110_3.png,img_110_4.png): 0.021
# (img_110_3.png,img_110_5.png): 0.032
# (img_110_3.png,img_110_6.png): 0.084
# (img_110_3.png,img_110_7.png): 0.151
# (img_110_3.png,img_110_8.png): 0.054
# (img_110_3.png,img_110_9.png): 0.028
# (img_110_4.png,img_110_5.png): 0.036
# (img_110_4.png,img_110_6.png): 0.118
# (img_110_4.png,img_110_7.png): 0.103
# (img_110_4.png,img_110_8.png): 0.029
# (img_110_4.png,img_110_9.png): 0.045
# (img_110_5.png,img_110_6.png): 0.143
# (img_110_5.png,img_110_7.png): 0.155
# (img_110_5.png,img_110_8.png): 0.028
# (img_110_5.png,img_110_9.png): 0.010
# (img_110_6.png,img_110_7.png): 0.241
# (img_110_6.png,img_110_8.png): 0.170
# (img_110_6.png,img_110_9.png): 0.131
# (img_110_7.png,img_110_8.png): 0.108
# (img_110_7.png,img_110_9.png): 0.166
# (img_110_8.png,img_110_9.png): 0.044
# Avg: 0.08890 +/- 0.00793
# (img_111_0.png,img_111_1.png): 0.110
# (img_111_0.png,img_111_2.png): 0.068
# (img_111_0.png,img_111_3.png): 0.074
# (img_111_0.png,img_111_4.png): 0.098
# (img_111_0.png,img_111_5.png): 0.078
# (img_111_0.png,img_111_6.png): 0.112
# (img_111_0.png,img_111_7.png): 0.191
# (img_111_0.png,img_111_8.png): 0.022
# (img_111_0.png,img_111_9.png): 0.057
# (img_111_1.png,img_111_2.png): 0.023
# (img_111_1.png,img_111_3.png): 0.207
# (img_111_1.png,img_111_4.png): 0.008
# (img_111_1.png,img_111_5.png): 0.025
# (img_111_1.png,img_111_6.png): 0.001
# (img_111_1.png,img_111_7.png): 0.252
# (img_111_1.png,img_111_8.png): 0.070
# (img_111_1.png,img_111_9.png): 0.099
# (img_111_2.png,img_111_3.png): 0.173
# (img_111_2.png,img_111_4.png): 0.013
# (img_111_2.png,img_111_5.png): 0.033
# (img_111_2.png,img_111_6.png): 0.025
# (img_111_2.png,img_111_7.png): 0.228
# (img_111_2.png,img_111_8.png): 0.045
# (img_111_2.png,img_111_9.png): 0.089
# (img_111_3.png,img_111_4.png): 0.200
# (img_111_3.png,img_111_5.png): 0.171
# (img_111_3.png,img_111_6.png): 0.208
# (img_111_3.png,img_111_7.png): 0.147
# (img_111_3.png,img_111_8.png): 0.113
# (img_111_3.png,img_111_9.png): 0.125
# (img_111_4.png,img_111_5.png): 0.036
# (img_111_4.png,img_111_6.png): 0.010
# (img_111_4.png,img_111_7.png): 0.250
# (img_111_4.png,img_111_8.png): 0.067
# (img_111_4.png,img_111_9.png): 0.106
# (img_111_5.png,img_111_6.png): 0.025
# (img_111_5.png,img_111_7.png): 0.233
# (img_111_5.png,img_111_8.png): 0.031
# (img_111_5.png,img_111_9.png): 0.047
# (img_111_6.png,img_111_7.png): 0.251
# (img_111_6.png,img_111_8.png): 0.071
# (img_111_6.png,img_111_9.png): 0.098
# (img_111_7.png,img_111_8.png): 0.209
# (img_111_7.png,img_111_9.png): 0.212
# (img_111_8.png,img_111_9.png): 0.024
# Avg: 0.10515 +/- 0.01166
# (img_112_0.png,img_112_1.png): 0.011
# (img_112_0.png,img_112_2.png): 0.271
# (img_112_0.png,img_112_3.png): 0.206
# (img_112_0.png,img_112_4.png): 0.145
# (img_112_0.png,img_112_5.png): 0.277
# (img_112_0.png,img_112_6.png): 0.352
# (img_112_0.png,img_112_7.png): 0.007
# (img_112_0.png,img_112_8.png): 0.133
# (img_112_0.png,img_112_9.png): 0.181
# (img_112_1.png,img_112_2.png): 0.266
# (img_112_1.png,img_112_3.png): 0.200
# (img_112_1.png,img_112_4.png): 0.135
# (img_112_1.png,img_112_5.png): 0.275
# (img_112_1.png,img_112_6.png): 0.349
# (img_112_1.png,img_112_7.png): 0.005
# (img_112_1.png,img_112_8.png): 0.117
# (img_112_1.png,img_112_9.png): 0.174
# (img_112_2.png,img_112_3.png): 0.047
# (img_112_2.png,img_112_4.png): 0.243
# (img_112_2.png,img_112_5.png): 0.040
# (img_112_2.png,img_112_6.png): 0.166
# (img_112_2.png,img_112_7.png): 0.264
# (img_112_2.png,img_112_8.png): 0.245
# (img_112_2.png,img_112_9.png): 0.215
# (img_112_3.png,img_112_4.png): 0.183
# (img_112_3.png,img_112_5.png): 0.072
# (img_112_3.png,img_112_6.png): 0.190
# (img_112_3.png,img_112_7.png): 0.199
# (img_112_3.png,img_112_8.png): 0.192
# (img_112_3.png,img_112_9.png): 0.185
# (img_112_4.png,img_112_5.png): 0.279
# (img_112_4.png,img_112_6.png): 0.313
# (img_112_4.png,img_112_7.png): 0.144
# (img_112_4.png,img_112_8.png): 0.062
# (img_112_4.png,img_112_9.png): 0.136
# (img_112_5.png,img_112_6.png): 0.144
# (img_112_5.png,img_112_7.png): 0.271
# (img_112_5.png,img_112_8.png): 0.282
# (img_112_5.png,img_112_9.png): 0.266
# (img_112_6.png,img_112_7.png): 0.350
# (img_112_6.png,img_112_8.png): 0.339
# (img_112_6.png,img_112_9.png): 0.350
# (img_112_7.png,img_112_8.png): 0.128
# (img_112_7.png,img_112_9.png): 0.177
# (img_112_8.png,img_112_9.png): 0.076
# Avg: 0.19257 +/- 0.01441
# (img_113_0.png,img_113_1.png): 0.241
# (img_113_0.png,img_113_2.png): 0.003
# (img_113_0.png,img_113_3.png): 0.179
# (img_113_0.png,img_113_4.png): 0.133
# (img_113_0.png,img_113_5.png): 0.007
# (img_113_0.png,img_113_6.png): 0.025
# (img_113_0.png,img_113_7.png): 0.198
# (img_113_0.png,img_113_8.png): 0.095
# (img_113_0.png,img_113_9.png): 0.060
# (img_113_1.png,img_113_2.png): 0.231
# (img_113_1.png,img_113_3.png): 0.183
# (img_113_1.png,img_113_4.png): 0.175
# (img_113_1.png,img_113_5.png): 0.236
# (img_113_1.png,img_113_6.png): 0.247
# (img_113_1.png,img_113_7.png): 0.281
# (img_113_1.png,img_113_8.png): 0.212
# (img_113_1.png,img_113_9.png): 0.186
# (img_113_2.png,img_113_3.png): 0.169
# (img_113_2.png,img_113_4.png): 0.122
# (img_113_2.png,img_113_5.png): 0.008
# (img_113_2.png,img_113_6.png): 0.025
# (img_113_2.png,img_113_7.png): 0.193
# (img_113_2.png,img_113_8.png): 0.086
# (img_113_2.png,img_113_9.png): 0.048
# (img_113_3.png,img_113_4.png): 0.022
# (img_113_3.png,img_113_5.png): 0.188
# (img_113_3.png,img_113_6.png): 0.161
# (img_113_3.png,img_113_7.png): 0.143
# (img_113_3.png,img_113_8.png): 0.077
# (img_113_3.png,img_113_9.png): 0.082
# (img_113_4.png,img_113_5.png): 0.141
# (img_113_4.png,img_113_6.png): 0.116
# (img_113_4.png,img_113_7.png): 0.141
# (img_113_4.png,img_113_8.png): 0.043
# (img_113_4.png,img_113_9.png): 0.038
# (img_113_5.png,img_113_6.png): 0.046
# (img_113_5.png,img_113_7.png): 0.212
# (img_113_5.png,img_113_8.png): 0.111
# (img_113_5.png,img_113_9.png): 0.066
# (img_113_6.png,img_113_7.png): 0.169
# (img_113_6.png,img_113_8.png): 0.060
# (img_113_6.png,img_113_9.png): 0.055
# (img_113_7.png,img_113_8.png): 0.103
# (img_113_7.png,img_113_9.png): 0.159
# (img_113_8.png,img_113_9.png): 0.035
# Avg: 0.12250 +/- 0.01126
# (img_114_0.png,img_114_1.png): 0.015
# (img_114_0.png,img_114_2.png): 0.003
# (img_114_0.png,img_114_3.png): 0.082
# (img_114_0.png,img_114_4.png): 0.102
# (img_114_0.png,img_114_5.png): 0.026
# (img_114_0.png,img_114_6.png): 0.013
# (img_114_0.png,img_114_7.png): 0.031
# (img_114_0.png,img_114_8.png): 0.328
# (img_114_0.png,img_114_9.png): 0.086
# (img_114_1.png,img_114_2.png): 0.009
# (img_114_1.png,img_114_3.png): 0.096
# (img_114_1.png,img_114_4.png): 0.120
# (img_114_1.png,img_114_5.png): 0.054
# (img_114_1.png,img_114_6.png): 0.018
# (img_114_1.png,img_114_7.png): 0.060
# (img_114_1.png,img_114_8.png): 0.328
# (img_114_1.png,img_114_9.png): 0.082
# (img_114_2.png,img_114_3.png): 0.084
# (img_114_2.png,img_114_4.png): 0.112
# (img_114_2.png,img_114_5.png): 0.038
# (img_114_2.png,img_114_6.png): 0.016
# (img_114_2.png,img_114_7.png): 0.042
# (img_114_2.png,img_114_8.png): 0.333
# (img_114_2.png,img_114_9.png): 0.081
# (img_114_3.png,img_114_4.png): 0.112
# (img_114_3.png,img_114_5.png): 0.090
# (img_114_3.png,img_114_6.png): 0.103
# (img_114_3.png,img_114_7.png): 0.065
# (img_114_3.png,img_114_8.png): 0.351
# (img_114_3.png,img_114_9.png): 0.036
# (img_114_4.png,img_114_5.png): 0.079
# (img_114_4.png,img_114_6.png): 0.103
# (img_114_4.png,img_114_7.png): 0.075
# (img_114_4.png,img_114_8.png): 0.318
# (img_114_4.png,img_114_9.png): 0.150
# (img_114_5.png,img_114_6.png): 0.034
# (img_114_5.png,img_114_7.png): 0.014
# (img_114_5.png,img_114_8.png): 0.326
# (img_114_5.png,img_114_9.png): 0.114
# (img_114_6.png,img_114_7.png): 0.049
# (img_114_6.png,img_114_8.png): 0.311
# (img_114_6.png,img_114_9.png): 0.102
# (img_114_7.png,img_114_8.png): 0.339
# (img_114_7.png,img_114_9.png): 0.097
# (img_114_8.png,img_114_9.png): 0.346
# Avg: 0.11940 +/- 0.01661
# (img_115_0.png,img_115_1.png): 0.084
# (img_115_0.png,img_115_2.png): 0.048
# (img_115_0.png,img_115_3.png): 0.074
# (img_115_0.png,img_115_4.png): 0.179
# (img_115_0.png,img_115_5.png): 0.023
# (img_115_0.png,img_115_6.png): 0.334
# (img_115_0.png,img_115_7.png): 0.035
# (img_115_0.png,img_115_8.png): 0.029
# (img_115_0.png,img_115_9.png): 0.092
# (img_115_1.png,img_115_2.png): 0.087
# (img_115_1.png,img_115_3.png): 0.062
# (img_115_1.png,img_115_4.png): 0.210
# (img_115_1.png,img_115_5.png): 0.050
# (img_115_1.png,img_115_6.png): 0.260
# (img_115_1.png,img_115_7.png): 0.053
# (img_115_1.png,img_115_8.png): 0.116
# (img_115_1.png,img_115_9.png): 0.011
# (img_115_2.png,img_115_3.png): 0.016
# (img_115_2.png,img_115_4.png): 0.105
# (img_115_2.png,img_115_5.png): 0.071
# (img_115_2.png,img_115_6.png): 0.351
# (img_115_2.png,img_115_7.png): 0.011
# (img_115_2.png,img_115_8.png): 0.020
# (img_115_2.png,img_115_9.png): 0.112
# (img_115_3.png,img_115_4.png): 0.107
# (img_115_3.png,img_115_5.png): 0.081
# (img_115_3.png,img_115_6.png): 0.327
# (img_115_3.png,img_115_7.png): 0.017
# (img_115_3.png,img_115_8.png): 0.051
# (img_115_3.png,img_115_9.png): 0.089
# (img_115_4.png,img_115_5.png): 0.204
# (img_115_4.png,img_115_6.png): 0.411
# (img_115_4.png,img_115_7.png): 0.139
# (img_115_4.png,img_115_8.png): 0.118
# (img_115_4.png,img_115_9.png): 0.235
# (img_115_5.png,img_115_6.png): 0.300
# (img_115_5.png,img_115_7.png): 0.041
# (img_115_5.png,img_115_8.png): 0.067
# (img_115_5.png,img_115_9.png): 0.050
# (img_115_6.png,img_115_7.png): 0.325
# (img_115_6.png,img_115_8.png): 0.369
# (img_115_6.png,img_115_9.png): 0.260
# (img_115_7.png,img_115_8.png): 0.031
# (img_115_7.png,img_115_9.png): 0.075
# (img_115_8.png,img_115_9.png): 0.135
# Avg: 0.13038 +/- 0.01674
# (img_116_0.png,img_116_1.png): 0.030
# (img_116_0.png,img_116_2.png): 0.079
# (img_116_0.png,img_116_3.png): 0.073
# (img_116_0.png,img_116_4.png): 0.039
# (img_116_0.png,img_116_5.png): 0.050
# (img_116_0.png,img_116_6.png): 0.233
# (img_116_0.png,img_116_7.png): 0.288
# (img_116_0.png,img_116_8.png): 0.080
# (img_116_0.png,img_116_9.png): 0.032
# (img_116_1.png,img_116_2.png): 0.026
# (img_116_1.png,img_116_3.png): 0.095
# (img_116_1.png,img_116_4.png): 0.009
# (img_116_1.png,img_116_5.png): 0.075
# (img_116_1.png,img_116_6.png): 0.249
# (img_116_1.png,img_116_7.png): 0.243
# (img_116_1.png,img_116_8.png): 0.036
# (img_116_1.png,img_116_9.png): 0.040
# (img_116_2.png,img_116_3.png): 0.132
# (img_116_2.png,img_116_4.png): 0.024
# (img_116_2.png,img_116_5.png): 0.119
# (img_116_2.png,img_116_6.png): 0.267
# (img_116_2.png,img_116_7.png): 0.205
# (img_116_2.png,img_116_8.png): 0.026
# (img_116_2.png,img_116_9.png): 0.079
# (img_116_3.png,img_116_4.png): 0.084
# (img_116_3.png,img_116_5.png): 0.009
# (img_116_3.png,img_116_6.png): 0.265
# (img_116_3.png,img_116_7.png): 0.287
# (img_116_3.png,img_116_8.png): 0.147
# (img_116_3.png,img_116_9.png): 0.031
# (img_116_4.png,img_116_5.png): 0.065
# (img_116_4.png,img_116_6.png): 0.264
# (img_116_4.png,img_116_7.png): 0.239
# (img_116_4.png,img_116_8.png): 0.051
# (img_116_4.png,img_116_9.png): 0.029
# (img_116_5.png,img_116_6.png): 0.257
# (img_116_5.png,img_116_7.png): 0.287
# (img_116_5.png,img_116_8.png): 0.135
# (img_116_5.png,img_116_9.png): 0.015
# (img_116_6.png,img_116_7.png): 0.331
# (img_116_6.png,img_116_8.png): 0.250
# (img_116_6.png,img_116_9.png): 0.261
# (img_116_7.png,img_116_8.png): 0.212
# (img_116_7.png,img_116_9.png): 0.271
# (img_116_8.png,img_116_9.png): 0.099
# Avg: 0.13595 +/- 0.01530
# (img_117_0.png,img_117_1.png): 0.023
# (img_117_0.png,img_117_2.png): 0.034
# (img_117_0.png,img_117_3.png): 0.017
# (img_117_0.png,img_117_4.png): 0.048
# (img_117_0.png,img_117_5.png): 0.063
# (img_117_0.png,img_117_6.png): 0.170
# (img_117_0.png,img_117_7.png): 0.045
# (img_117_0.png,img_117_8.png): 0.091
# (img_117_0.png,img_117_9.png): 0.037
# (img_117_1.png,img_117_2.png): 0.077
# (img_117_1.png,img_117_3.png): 0.002
# (img_117_1.png,img_117_4.png): 0.015
# (img_117_1.png,img_117_5.png): 0.041
# (img_117_1.png,img_117_6.png): 0.162
# (img_117_1.png,img_117_7.png): 0.017
# (img_117_1.png,img_117_8.png): 0.057
# (img_117_1.png,img_117_9.png): 0.081
# (img_117_2.png,img_117_3.png): 0.068
# (img_117_2.png,img_117_4.png): 0.105
# (img_117_2.png,img_117_5.png): 0.111
# (img_117_2.png,img_117_6.png): 0.191
# (img_117_2.png,img_117_7.png): 0.102
# (img_117_2.png,img_117_8.png): 0.142
# (img_117_2.png,img_117_9.png): 0.001
# (img_117_3.png,img_117_4.png): 0.022
# (img_117_3.png,img_117_5.png): 0.048
# (img_117_3.png,img_117_6.png): 0.168
# (img_117_3.png,img_117_7.png): 0.024
# (img_117_3.png,img_117_8.png): 0.067
# (img_117_3.png,img_117_9.png): 0.072
# (img_117_4.png,img_117_5.png): 0.032
# (img_117_4.png,img_117_6.png): 0.136
# (img_117_4.png,img_117_7.png): 0.013
# (img_117_4.png,img_117_8.png): 0.023
# (img_117_4.png,img_117_9.png): 0.108
# (img_117_5.png,img_117_6.png): 0.096
# (img_117_5.png,img_117_7.png): 0.015
# (img_117_5.png,img_117_8.png): 0.045
# (img_117_5.png,img_117_9.png): 0.114
# (img_117_6.png,img_117_7.png): 0.128
# (img_117_6.png,img_117_8.png): 0.103
# (img_117_6.png,img_117_9.png): 0.191
# (img_117_7.png,img_117_8.png): 0.036
# (img_117_7.png,img_117_9.png): 0.105
# (img_117_8.png,img_117_9.png): 0.144
# Avg: 0.07530 +/- 0.00791
# (img_118_0.png,img_118_1.png): 0.275
# (img_118_0.png,img_118_2.png): 0.326
# (img_118_0.png,img_118_3.png): 0.318
# (img_118_0.png,img_118_4.png): 0.299
# (img_118_0.png,img_118_5.png): 0.332
# (img_118_0.png,img_118_6.png): 0.227
# (img_118_0.png,img_118_7.png): 0.275
# (img_118_0.png,img_118_8.png): 0.318
# (img_118_0.png,img_118_9.png): 0.216
# (img_118_1.png,img_118_2.png): 0.065
# (img_118_1.png,img_118_3.png): 0.051
# (img_118_1.png,img_118_4.png): 0.412
# (img_118_1.png,img_118_5.png): 0.075
# (img_118_1.png,img_118_6.png): 0.110
# (img_118_1.png,img_118_7.png): 0.163
# (img_118_1.png,img_118_8.png): 0.054
# (img_118_1.png,img_118_9.png): 0.260
# (img_118_2.png,img_118_3.png): 0.003
# (img_118_2.png,img_118_4.png): 0.400
# (img_118_2.png,img_118_5.png): 0.005
# (img_118_2.png,img_118_6.png): 0.197
# (img_118_2.png,img_118_7.png): 0.172
# (img_118_2.png,img_118_8.png): 0.004
# (img_118_2.png,img_118_9.png): 0.275
# (img_118_3.png,img_118_4.png): 0.401
# (img_118_3.png,img_118_5.png): 0.010
# (img_118_3.png,img_118_6.png): 0.186
# (img_118_3.png,img_118_7.png): 0.169
# (img_118_3.png,img_118_8.png): 0.001
# (img_118_3.png,img_118_9.png): 0.271
# (img_118_4.png,img_118_5.png): 0.409
# (img_118_4.png,img_118_6.png): 0.365
# (img_118_4.png,img_118_7.png): 0.296
# (img_118_4.png,img_118_8.png): 0.404
# (img_118_4.png,img_118_9.png): 0.180
# (img_118_5.png,img_118_6.png): 0.209
# (img_118_5.png,img_118_7.png): 0.191
# (img_118_5.png,img_118_8.png): 0.010
# (img_118_5.png,img_118_9.png): 0.288
# (img_118_6.png,img_118_7.png): 0.120
# (img_118_6.png,img_118_8.png): 0.188
# (img_118_6.png,img_118_9.png): 0.176
# (img_118_7.png,img_118_8.png): 0.171
# (img_118_7.png,img_118_9.png): 0.105
# (img_118_8.png,img_118_9.png): 0.273
# Avg: 0.20564 +/- 0.01845
# (img_119_0.png,img_119_1.png): 0.161
# (img_119_0.png,img_119_2.png): 0.068
# (img_119_0.png,img_119_3.png): 0.117
# (img_119_0.png,img_119_4.png): 0.152
# (img_119_0.png,img_119_5.png): 0.071
# (img_119_0.png,img_119_6.png): 0.053
# (img_119_0.png,img_119_7.png): 0.300
# (img_119_0.png,img_119_8.png): 0.050
# (img_119_0.png,img_119_9.png): 0.018
# (img_119_1.png,img_119_2.png): 0.224
# (img_119_1.png,img_119_3.png): 0.235
# (img_119_1.png,img_119_4.png): 0.268
# (img_119_1.png,img_119_5.png): 0.187
# (img_119_1.png,img_119_6.png): 0.216
# (img_119_1.png,img_119_7.png): 0.273
# (img_119_1.png,img_119_8.png): 0.162
# (img_119_1.png,img_119_9.png): 0.186
# (img_119_2.png,img_119_3.png): 0.075
# (img_119_2.png,img_119_4.png): 0.150
# (img_119_2.png,img_119_5.png): 0.122
# (img_119_2.png,img_119_6.png): 0.017
# (img_119_2.png,img_119_7.png): 0.333
# (img_119_2.png,img_119_8.png): 0.124
# (img_119_2.png,img_119_9.png): 0.049
# (img_119_3.png,img_119_4.png): 0.121
# (img_119_3.png,img_119_5.png): 0.112
# (img_119_3.png,img_119_6.png): 0.064
# (img_119_3.png,img_119_7.png): 0.312
# (img_119_3.png,img_119_8.png): 0.124
# (img_119_3.png,img_119_9.png): 0.091
# (img_119_4.png,img_119_5.png): 0.068
# (img_119_4.png,img_119_6.png): 0.129
# (img_119_4.png,img_119_7.png): 0.246
# (img_119_4.png,img_119_8.png): 0.113
# (img_119_4.png,img_119_9.png): 0.137
# (img_119_5.png,img_119_6.png): 0.099
# (img_119_5.png,img_119_7.png): 0.256
# (img_119_5.png,img_119_8.png): 0.019
# (img_119_5.png,img_119_9.png): 0.077
# (img_119_6.png,img_119_7.png): 0.316
# (img_119_6.png,img_119_8.png): 0.101
# (img_119_6.png,img_119_9.png): 0.025
# (img_119_7.png,img_119_8.png): 0.272
# (img_119_7.png,img_119_9.png): 0.302
# (img_119_8.png,img_119_9.png): 0.068
# Avg: 0.14811 +/- 0.01362
# (img_120_0.png,img_120_1.png): 0.034
# (img_120_0.png,img_120_2.png): 0.289
# (img_120_0.png,img_120_3.png): 0.194
# (img_120_0.png,img_120_4.png): 0.204
# (img_120_0.png,img_120_5.png): 0.169
# (img_120_0.png,img_120_6.png): 0.252
# (img_120_0.png,img_120_7.png): 0.014
# (img_120_0.png,img_120_8.png): 0.122
# (img_120_0.png,img_120_9.png): 0.056
# ...
# (img_190_3.png,img_190_6.png): 0.143
# (img_190_3.png,img_190_7.png): 0.051
# (img_190_3.png,img_190_8.png): 0.166
# (img_190_3.png,img_190_9.png): 0.028
# (img_190_4.png,img_190_5.png): 0.034
# (img_190_4.png,img_190_6.png): 0.053
# (img_190_4.png,img_190_7.png): 0.025
# (img_190_4.png,img_190_8.png): 0.164
# (img_190_4.png,img_190_9.png): 0.064
# (img_190_5.png,img_190_6.png): 0.082
# (img_190_5.png,img_190_7.png): 0.006
# (img_190_5.png,img_190_8.png): 0.121
# (img_190_5.png,img_190_9.png): 0.048
# (img_190_6.png,img_190_7.png): 0.086
# (img_190_6.png,img_190_8.png): 0.170
# (img_190_6.png,img_190_9.png): 0.132
# (img_190_7.png,img_190_8.png): 0.134
# (img_190_7.png,img_190_9.png): 0.032
# (img_190_8.png,img_190_9.png): 0.163
# Avg: 0.07205 +/- 0.00751
# (img_191_0.png,img_191_1.png): 0.388
# (img_191_0.png,img_191_2.png): 0.429
# (img_191_0.png,img_191_3.png): 0.412
# (img_191_0.png,img_191_4.png): 0.393
# (img_191_0.png,img_191_5.png): 0.405
# (img_191_0.png,img_191_6.png): 0.394
# (img_191_0.png,img_191_7.png): 0.345
# (img_191_0.png,img_191_8.png): 0.409
# (img_191_0.png,img_191_9.png): 0.431
# (img_191_1.png,img_191_2.png): 0.127
# (img_191_1.png,img_191_3.png): 0.193
# (img_191_1.png,img_191_4.png): 0.076
# (img_191_1.png,img_191_5.png): 0.018
# (img_191_1.png,img_191_6.png): 0.084
# (img_191_1.png,img_191_7.png): 0.067
# (img_191_1.png,img_191_8.png): 0.011
# (img_191_1.png,img_191_9.png): 0.139
# (img_191_2.png,img_191_3.png): 0.267
# (img_191_2.png,img_191_4.png): 0.039
# (img_191_2.png,img_191_5.png): 0.093
# (img_191_2.png,img_191_6.png): 0.031
# (img_191_2.png,img_191_7.png): 0.201
# (img_191_2.png,img_191_8.png): 0.134
# (img_191_2.png,img_191_9.png): 0.227
# (img_191_3.png,img_191_4.png): 0.249
# (img_191_3.png,img_191_5.png): 0.198
# (img_191_3.png,img_191_6.png): 0.250
# (img_191_3.png,img_191_7.png): 0.194
# (img_191_3.png,img_191_8.png): 0.187
# (img_191_3.png,img_191_9.png): 0.040
# (img_191_4.png,img_191_5.png): 0.061
# (img_191_4.png,img_191_6.png): 0.003
# (img_191_4.png,img_191_7.png): 0.154
# (img_191_4.png,img_191_8.png): 0.095
# (img_191_4.png,img_191_9.png): 0.206
# (img_191_5.png,img_191_6.png): 0.066
# (img_191_5.png,img_191_7.png): 0.092
# (img_191_5.png,img_191_8.png): 0.015
# (img_191_5.png,img_191_9.png): 0.142
# (img_191_6.png,img_191_7.png): 0.161
# (img_191_6.png,img_191_8.png): 0.103
# (img_191_6.png,img_191_9.png): 0.209
# (img_191_7.png,img_191_8.png): 0.070
# (img_191_7.png,img_191_9.png): 0.162
# (img_191_8.png,img_191_9.png): 0.128
# Avg: 0.18001 +/- 0.01928
# (img_192_0.png,img_192_1.png): 0.059
# (img_192_0.png,img_192_2.png): 0.097
# (img_192_0.png,img_192_3.png): 0.121
# (img_192_0.png,img_192_4.png): 0.086
# (img_192_0.png,img_192_5.png): 0.003
# (img_192_0.png,img_192_6.png): 0.126
# (img_192_0.png,img_192_7.png): 0.320
# (img_192_0.png,img_192_8.png): 0.449
# (img_192_0.png,img_192_9.png): 0.132
# (img_192_1.png,img_192_2.png): 0.129
# (img_192_1.png,img_192_3.png): 0.041
# (img_192_1.png,img_192_4.png): 0.011
# (img_192_1.png,img_192_5.png): 0.062
# (img_192_1.png,img_192_6.png): 0.111
# (img_192_1.png,img_192_7.png): 0.299
# (img_192_1.png,img_192_8.png): 0.443
# (img_192_1.png,img_192_9.png): 0.064
# (img_192_2.png,img_192_3.png): 0.184
# (img_192_2.png,img_192_4.png): 0.157
# (img_192_2.png,img_192_5.png): 0.082
# (img_192_2.png,img_192_6.png): 0.104
# (img_192_2.png,img_192_7.png): 0.341
# (img_192_2.png,img_192_8.png): 0.458
# (img_192_2.png,img_192_9.png): 0.205
# (img_192_3.png,img_192_4.png): 0.013
# (img_192_3.png,img_192_5.png): 0.128
# (img_192_3.png,img_192_6.png): 0.175
# (img_192_3.png,img_192_7.png): 0.327
# (img_192_3.png,img_192_8.png): 0.472
# (img_192_3.png,img_192_9.png): 0.010
# (img_192_4.png,img_192_5.png): 0.092
# (img_192_4.png,img_192_6.png): 0.142
# (img_192_4.png,img_192_7.png): 0.309
# (img_192_4.png,img_192_8.png): 0.455
# (img_192_4.png,img_192_9.png): 0.031
# (img_192_5.png,img_192_6.png): 0.118
# (img_192_5.png,img_192_7.png): 0.321
# (img_192_5.png,img_192_8.png): 0.446
# (img_192_5.png,img_192_9.png): 0.141
# (img_192_6.png,img_192_7.png): 0.282
# (img_192_6.png,img_192_8.png): 0.453
# (img_192_6.png,img_192_9.png): 0.206
# (img_192_7.png,img_192_8.png): 0.343
# (img_192_7.png,img_192_9.png): 0.347
# (img_192_8.png,img_192_9.png): 0.485
# Avg: 0.20845 +/- 0.02256
# (img_193_0.png,img_193_1.png): 0.324
# (img_193_0.png,img_193_2.png): 0.210
# (img_193_0.png,img_193_3.png): 0.258
# (img_193_0.png,img_193_4.png): 0.107
# (img_193_0.png,img_193_5.png): 0.016
# (img_193_0.png,img_193_6.png): 0.362
# (img_193_0.png,img_193_7.png): 0.258
# (img_193_0.png,img_193_8.png): 0.312
# (img_193_0.png,img_193_9.png): 0.025
# (img_193_1.png,img_193_2.png): 0.159
# (img_193_1.png,img_193_3.png): 0.091
# (img_193_1.png,img_193_4.png): 0.225
# (img_193_1.png,img_193_5.png): 0.326
# (img_193_1.png,img_193_6.png): 0.250
# (img_193_1.png,img_193_7.png): 0.356
# (img_193_1.png,img_193_8.png): 0.338
# (img_193_1.png,img_193_9.png): 0.319
# (img_193_2.png,img_193_3.png): 0.041
# (img_193_2.png,img_193_4.png): 0.161
# (img_193_2.png,img_193_5.png): 0.225
# (img_193_2.png,img_193_6.png): 0.355
# (img_193_2.png,img_193_7.png): 0.358
# (img_193_2.png,img_193_8.png): 0.376
# (img_193_2.png,img_193_9.png): 0.222
# (img_193_3.png,img_193_4.png): 0.174
# (img_193_3.png,img_193_5.png): 0.266
# (img_193_3.png,img_193_6.png): 0.324
# (img_193_3.png,img_193_7.png): 0.368
# (img_193_3.png,img_193_8.png): 0.367
# (img_193_3.png,img_193_9.png): 0.260
# (img_193_4.png,img_193_5.png): 0.103
# (img_193_4.png,img_193_6.png): 0.277
# (img_193_4.png,img_193_7.png): 0.223
# (img_193_4.png,img_193_8.png): 0.283
# (img_193_4.png,img_193_9.png): 0.089
# (img_193_5.png,img_193_6.png): 0.358
# (img_193_5.png,img_193_7.png): 0.240
# (img_193_5.png,img_193_8.png): 0.301
# (img_193_5.png,img_193_9.png): 0.006
# (img_193_6.png,img_193_7.png): 0.252
# (img_193_6.png,img_193_8.png): 0.147
# (img_193_6.png,img_193_9.png): 0.352
# (img_193_7.png,img_193_8.png): 0.130
# (img_193_7.png,img_193_9.png): 0.231
# (img_193_8.png,img_193_9.png): 0.295
# Avg: 0.23815 +/- 0.01570
# (img_194_0.png,img_194_1.png): 0.023
# (img_194_0.png,img_194_2.png): 0.042
# (img_194_0.png,img_194_3.png): 0.118
# (img_194_0.png,img_194_4.png): 0.022
# (img_194_0.png,img_194_5.png): 0.122
# (img_194_0.png,img_194_6.png): 0.162
# (img_194_0.png,img_194_7.png): 0.063
# (img_194_0.png,img_194_8.png): 0.023
# (img_194_0.png,img_194_9.png): 0.015
# (img_194_1.png,img_194_2.png): 0.076
# (img_194_1.png,img_194_3.png): 0.122
# (img_194_1.png,img_194_4.png): 0.040
# (img_194_1.png,img_194_5.png): 0.100
# (img_194_1.png,img_194_6.png): 0.143
# (img_194_1.png,img_194_7.png): 0.028
# (img_194_1.png,img_194_8.png): 0.020
# (img_194_1.png,img_194_9.png): 0.045
# (img_194_2.png,img_194_3.png): 0.062
# (img_194_2.png,img_194_4.png): 0.067
# (img_194_2.png,img_194_5.png): 0.098
# (img_194_2.png,img_194_6.png): 0.133
# (img_194_2.png,img_194_7.png): 0.100
# (img_194_2.png,img_194_8.png): 0.078
# (img_194_2.png,img_194_9.png): 0.051
# (img_194_3.png,img_194_4.png): 0.145
# (img_194_3.png,img_194_5.png): 0.049
# (img_194_3.png,img_194_6.png): 0.071
# (img_194_3.png,img_194_7.png): 0.114
# (img_194_3.png,img_194_8.png): 0.139
# (img_194_3.png,img_194_9.png): 0.143
# (img_194_4.png,img_194_5.png): 0.152
# (img_194_4.png,img_194_6.png): 0.193
# (img_194_4.png,img_194_7.png): 0.081
# (img_194_4.png,img_194_8.png): 0.010
# (img_194_4.png,img_194_9.png): 0.010
# (img_194_5.png,img_194_6.png): 0.016
# (img_194_5.png,img_194_7.png): 0.065
# (img_194_5.png,img_194_8.png): 0.134
# (img_194_5.png,img_194_9.png): 0.153
# (img_194_6.png,img_194_7.png): 0.107
# (img_194_6.png,img_194_8.png): 0.177
# (img_194_6.png,img_194_9.png): 0.192
# (img_194_7.png,img_194_8.png): 0.058
# (img_194_7.png,img_194_9.png): 0.090
# (img_194_8.png,img_194_9.png): 0.025
# Avg: 0.08618 +/- 0.00785
# (img_195_0.png,img_195_1.png): 0.107
# (img_195_0.png,img_195_2.png): 0.076
# (img_195_0.png,img_195_3.png): 0.206
# (img_195_0.png,img_195_4.png): 0.083
# (img_195_0.png,img_195_5.png): 0.127
# (img_195_0.png,img_195_6.png): 0.084
# (img_195_0.png,img_195_7.png): 0.061
# (img_195_0.png,img_195_8.png): 0.045
# (img_195_0.png,img_195_9.png): 0.233
# (img_195_1.png,img_195_2.png): 0.066
# (img_195_1.png,img_195_3.png): 0.157
# (img_195_1.png,img_195_4.png): 0.050
# (img_195_1.png,img_195_5.png): 0.111
# (img_195_1.png,img_195_6.png): 0.096
# (img_195_1.png,img_195_7.png): 0.030
# (img_195_1.png,img_195_8.png): 0.060
# (img_195_1.png,img_195_9.png): 0.308
# (img_195_2.png,img_195_3.png): 0.115
# (img_195_2.png,img_195_4.png): 0.007
# (img_195_2.png,img_195_5.png): 0.031
# (img_195_2.png,img_195_6.png): 0.016
# (img_195_2.png,img_195_7.png): 0.037
# (img_195_2.png,img_195_8.png): 0.021
# (img_195_2.png,img_195_9.png): 0.300
# (img_195_3.png,img_195_4.png): 0.120
# (img_195_3.png,img_195_5.png): 0.070
# (img_195_3.png,img_195_6.png): 0.117
# (img_195_3.png,img_195_7.png): 0.164
# (img_195_3.png,img_195_8.png): 0.157
# (img_195_3.png,img_195_9.png): 0.384
# (img_195_4.png,img_195_5.png): 0.037
# (img_195_4.png,img_195_6.png): 0.024
# (img_195_4.png,img_195_7.png): 0.025
# (img_195_4.png,img_195_8.png): 0.018
# (img_195_4.png,img_195_9.png): 0.302
# (img_195_5.png,img_195_6.png): 0.021
# (img_195_5.png,img_195_7.png): 0.089
# (img_195_5.png,img_195_8.png): 0.067
# (img_195_5.png,img_195_9.png): 0.328
# (img_195_6.png,img_195_7.png): 0.059
# (img_195_6.png,img_195_8.png): 0.033
# (img_195_6.png,img_195_9.png): 0.291
# (img_195_7.png,img_195_8.png): 0.018
# (img_195_7.png,img_195_9.png): 0.283
# (img_195_8.png,img_195_9.png): 0.269
# Avg: 0.11779 +/- 0.01527
# (img_196_0.png,img_196_1.png): 0.044
# (img_196_0.png,img_196_2.png): 0.042
# (img_196_0.png,img_196_3.png): 0.199
# (img_196_0.png,img_196_4.png): 0.121
# (img_196_0.png,img_196_5.png): 0.105
# (img_196_0.png,img_196_6.png): 0.082
# (img_196_0.png,img_196_7.png): 0.087
# (img_196_0.png,img_196_8.png): 0.044
# (img_196_0.png,img_196_9.png): 0.087
# (img_196_1.png,img_196_2.png): 0.072
# (img_196_1.png,img_196_3.png): 0.178
# (img_196_1.png,img_196_4.png): 0.161
# (img_196_1.png,img_196_5.png): 0.146
# (img_196_1.png,img_196_6.png): 0.116
# (img_196_1.png,img_196_7.png): 0.122
# (img_196_1.png,img_196_8.png): 0.091
# (img_196_1.png,img_196_9.png): 0.128
# (img_196_2.png,img_196_3.png): 0.239
# (img_196_2.png,img_196_4.png): 0.077
# (img_196_2.png,img_196_5.png): 0.060
# (img_196_2.png,img_196_6.png): 0.029
# (img_196_2.png,img_196_7.png): 0.034
# (img_196_2.png,img_196_8.png): 0.015
# (img_196_2.png,img_196_9.png): 0.036
# (img_196_3.png,img_196_4.png): 0.269
# (img_196_3.png,img_196_5.png): 0.269
# (img_196_3.png,img_196_6.png): 0.261
# (img_196_3.png,img_196_7.png): 0.262
# (img_196_3.png,img_196_8.png): 0.240
# (img_196_3.png,img_196_9.png): 0.267
# (img_196_4.png,img_196_5.png): 0.007
# (img_196_4.png,img_196_6.png): 0.029
# (img_196_4.png,img_196_7.png): 0.024
# (img_196_4.png,img_196_8.png): 0.060
# (img_196_4.png,img_196_9.png): 0.021
# (img_196_5.png,img_196_6.png): 0.018
# (img_196_5.png,img_196_7.png): 0.014
# (img_196_5.png,img_196_8.png): 0.046
# (img_196_5.png,img_196_9.png): 0.011
# (img_196_6.png,img_196_7.png): 0.001
# (img_196_6.png,img_196_8.png): 0.025
# (img_196_6.png,img_196_9.png): 0.006
# (img_196_7.png,img_196_8.png): 0.030
# (img_196_7.png,img_196_9.png): 0.006
# (img_196_8.png,img_196_9.png): 0.023
# Avg: 0.09344 +/- 0.01272
# (img_197_0.png,img_197_1.png): 0.015
# (img_197_0.png,img_197_2.png): 0.095
# (img_197_0.png,img_197_3.png): 0.233
# (img_197_0.png,img_197_4.png): 0.045
# (img_197_0.png,img_197_5.png): 0.164
# (img_197_0.png,img_197_6.png): 0.123
# (img_197_0.png,img_197_7.png): 0.002
# (img_197_0.png,img_197_8.png): 0.095
# (img_197_0.png,img_197_9.png): 0.134
# (img_197_1.png,img_197_2.png): 0.081
# (img_197_1.png,img_197_3.png): 0.245
# (img_197_1.png,img_197_4.png): 0.066
# (img_197_1.png,img_197_5.png): 0.147
# (img_197_1.png,img_197_6.png): 0.131
# (img_197_1.png,img_197_7.png): 0.014
# (img_197_1.png,img_197_8.png): 0.092
# (img_197_1.png,img_197_9.png): 0.114
# (img_197_2.png,img_197_3.png): 0.276
# (img_197_2.png,img_197_4.png): 0.078
# (img_197_2.png,img_197_5.png): 0.063
# (img_197_2.png,img_197_6.png): 0.056
# (img_197_2.png,img_197_7.png): 0.103
# (img_197_2.png,img_197_8.png): 0.014
# (img_197_2.png,img_197_9.png): 0.032
# (img_197_3.png,img_197_4.png): 0.226
# (img_197_3.png,img_197_5.png): 0.312
# (img_197_3.png,img_197_6.png): 0.267
# (img_197_3.png,img_197_7.png): 0.232
# (img_197_3.png,img_197_8.png): 0.266
# (img_197_3.png,img_197_9.png): 0.297
# (img_197_4.png,img_197_5.png): 0.152
# (img_197_4.png,img_197_6.png): 0.073
# (img_197_4.png,img_197_7.png): 0.056
# (img_197_4.png,img_197_8.png): 0.066
# (img_197_4.png,img_197_9.png): 0.126
# (img_197_5.png,img_197_6.png): 0.110
# (img_197_5.png,img_197_7.png): 0.170
# (img_197_5.png,img_197_8.png): 0.074
# (img_197_5.png,img_197_9.png): 0.042
# (img_197_6.png,img_197_7.png): 0.135
# (img_197_6.png,img_197_8.png): 0.030
# (img_197_6.png,img_197_9.png): 0.106
# (img_197_7.png,img_197_8.png): 0.105
# (img_197_7.png,img_197_9.png): 0.140
# (img_197_8.png,img_197_9.png): 0.062
# Avg: 0.12147 +/- 0.01219
# (img_198_0.png,img_198_1.png): 0.267
# (img_198_0.png,img_198_2.png): 0.011
# (img_198_0.png,img_198_3.png): 0.269
# (img_198_0.png,img_198_4.png): 0.276
# (img_198_0.png,img_198_5.png): 0.113
# (img_198_0.png,img_198_6.png): 0.247
# (img_198_0.png,img_198_7.png): 0.248
# (img_198_0.png,img_198_8.png): 0.236
# (img_198_0.png,img_198_9.png): 0.015
# (img_198_1.png,img_198_2.png): 0.285
# (img_198_1.png,img_198_3.png): 0.179
# (img_198_1.png,img_198_4.png): 0.207
# (img_198_1.png,img_198_5.png): 0.151
# (img_198_1.png,img_198_6.png): 0.125
# (img_198_1.png,img_198_7.png): 0.135
# (img_198_1.png,img_198_8.png): 0.028
# (img_198_1.png,img_198_9.png): 0.296
# (img_198_2.png,img_198_3.png): 0.272
# (img_198_2.png,img_198_4.png): 0.279
# (img_198_2.png,img_198_5.png): 0.121
# (img_198_2.png,img_198_6.png): 0.248
# (img_198_2.png,img_198_7.png): 0.248
# (img_198_2.png,img_198_8.png): 0.253
# (img_198_2.png,img_198_9.png): 0.004
# (img_198_3.png,img_198_4.png): 0.020
# (img_198_3.png,img_198_5.png): 0.209
# (img_198_3.png,img_198_6.png): 0.048
# (img_198_3.png,img_198_7.png): 0.041
# (img_198_3.png,img_198_8.png): 0.170
# (img_198_3.png,img_198_9.png): 0.285
# (img_198_4.png,img_198_5.png): 0.230
# (img_198_4.png,img_198_6.png): 0.081
# (img_198_4.png,img_198_7.png): 0.073
# (img_198_4.png,img_198_8.png): 0.197
# (img_198_4.png,img_198_9.png): 0.291
# (img_198_5.png,img_198_6.png): 0.153
# (img_198_5.png,img_198_7.png): 0.156
# (img_198_5.png,img_198_8.png): 0.105
# (img_198_5.png,img_198_9.png): 0.131
# (img_198_6.png,img_198_7.png): 0.002
# (img_198_6.png,img_198_8.png): 0.104
# (img_198_6.png,img_198_9.png): 0.260
# (img_198_7.png,img_198_8.png): 0.114
# (img_198_7.png,img_198_9.png): 0.260
# (img_198_8.png,img_198_9.png): 0.265
# Avg: 0.17130 +/- 0.01399
# (img_199_0.png,img_199_1.png): 0.071
# (img_199_0.png,img_199_2.png): 0.099
# (img_199_0.png,img_199_3.png): 0.007
# (img_199_0.png,img_199_4.png): 0.026
# (img_199_0.png,img_199_5.png): 0.071
# (img_199_0.png,img_199_6.png): 0.077
# (img_199_0.png,img_199_7.png): 0.080
# (img_199_0.png,img_199_8.png): 0.106
# (img_199_0.png,img_199_9.png): 0.039
# (img_199_1.png,img_199_2.png): 0.009
# (img_199_1.png,img_199_3.png): 0.070
# (img_199_1.png,img_199_4.png): 0.046
# (img_199_1.png,img_199_5.png): 0.001
# (img_199_1.png,img_199_6.png): 0.004
# (img_199_1.png,img_199_7.png): 0.004
# (img_199_1.png,img_199_8.png): 0.010
# (img_199_1.png,img_199_9.png): 0.110
# (img_199_2.png,img_199_3.png): 0.099
# (img_199_2.png,img_199_4.png): 0.075
# (img_199_2.png,img_199_5.png): 0.012
# (img_199_2.png,img_199_6.png): 0.005
# (img_199_2.png,img_199_7.png): 0.004
# (img_199_2.png,img_199_8.png): 0.007
# (img_199_2.png,img_199_9.png): 0.140
# (img_199_3.png,img_199_4.png): 0.014
# (img_199_3.png,img_199_5.png): 0.066
# (img_199_3.png,img_199_6.png): 0.079
# (img_199_3.png,img_199_7.png): 0.082
# (img_199_3.png,img_199_8.png): 0.101
# (img_199_3.png,img_199_9.png): 0.023
# (img_199_4.png,img_199_5.png): 0.040
# (img_199_4.png,img_199_6.png): 0.057
# (img_199_4.png,img_199_7.png): 0.060
# (img_199_4.png,img_199_8.png): 0.072
# (img_199_4.png,img_199_9.png): 0.035
# (img_199_5.png,img_199_6.png): 0.008
# (img_199_5.png,img_199_7.png): 0.008
# (img_199_5.png,img_199_8.png): 0.010
# (img_199_5.png,img_199_9.png): 0.103
# (img_199_6.png,img_199_7.png): 0.000
# (img_199_6.png,img_199_8.png): 0.014
# (img_199_6.png,img_199_9.png): 0.122
# (img_199_7.png,img_199_8.png): 0.012
# (img_199_7.png,img_199_9.png): 0.124
# (img_199_8.png,img_199_9.png): 0.136
# Avg: 0.05196 +/- 0.00635
#
#
# Avg across all test sets: 0.13803
